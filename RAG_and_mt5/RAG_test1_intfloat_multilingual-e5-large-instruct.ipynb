# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

dir = '/content/drive/MyDrive/Project1/Data/Training/Tables'
files = os.listdir(dir)

# %%
for file in files:
  print(file)
# Out:
# seouldata_healthcare_db_annotation.json
# seouldata_culture_db_annotation.json
# seouldata_publicadministration_db_annotation.json
# seouldata_industrialeconomic_db_annotation.json
# seouldata_welfare_db_annotation.json
# seouldata_climate_db_annotation.json
# seouldata_transportation_db_annotation.json
# seouldata_education_db_annotation.json
# publicdata_publicadministration_db_annotation.json
# publicdata_healthcare_db_annotation.json
# publicdata_industrialeconomic_db_annotation.json
# publicdata_culture_db_annotation.json
# publicdata_climate_db_annotation.json
# publicdata_welfare_db_annotation.json
# publicdata_transportation_db_annotation.json
# seoulpopulation_publicadministration_db_annotation.json
# publicdata_education_db_annotation.json

# %%
import json
import pandas as pd

# %%
'''
file_path = dir + '/' + files[0]

with open(file_path, "r", encoding="utf-8") as file:
    data = json.load(file)
'''
# Out:
# '\nfile_path = dir + \'/\' + files[0]\n\nwith open(file_path, "r", encoding="utf-8") as file:\n    data = json.load(file)\n'

# %%
'''
df_ex = pd.DataFrame(data["data"])
df_ex.info()
'''
# Out:
# '\ndf_ex = pd.DataFrame(data["data"])\ndf_ex.info()\n'

# %%
df = pd.DataFrame()

for filename in os.listdir(dir):
  if filename.endswith('.json'):
    filepath = os.path.join(dir, filename)
    with open(filepath, 'r') as f:
      data = json.load(f)
      df_temp = pd.DataFrame(data["data"])
      df = pd.concat([df, df_temp])

# %%
df.head()
# Out:
#   source                     db_id        table_names_original  \
# 0  서울특별시  seouldata_healthcare_455  [SEOUL_PUBLIC_HYGIENE_BIZ]
# 1  서울특별시  seouldata_healthcare_408  [L_O_C_A_L_D_A_T_A_072211]
# 2  서울특별시  seouldata_healthcare_658  [L_O_C_A_L_D_A_T_A_010110]
# 3  서울특별시  seouldata_healthcare_686  [L_O_C_A_L_D_A_T_A_020304]
# 4  서울특별시  seouldata_healthcare_694              [F81_OPEN_TBL]
#
#                         table_names  \
# 0              [서울시 기타 위생용품 제조업 현황]
# 1              [서울시 식품제조가공업 인허가 정보]
# 2                [서울시 의료유사업 인허가 정보]
# 3            [서울시 동물용의약품도매상 인허가 정보]
# 4  [서울시 정신건강복지센터 등록회원의 지역사회 생활 유지율]
#
#                                column_names_original  \
# 0  [[-1, *], [0, CGG_CODE], [0, SNT_COB_CODE], [0...
# 1  [[-1, *], [0, OPNSFTEAMCODE], [0, MGTNO], [0, ...
# 2  [[-1, *], [0, OPNSFTEAMCODE], [0, MGTNO], [0, ...
# 3  [[-1, *], [0, OPNSFTEAMCODE], [0, MGTNO], [0, ...
# 4  [[-1, *], [0, STAT_YEAR], [0, AREA_NAME], [0, ...
#
#                                         column_names  \
# 0  [[-1, *], [0, 시군구코드], [0, 업종코드], [0, 년도], [0, ...
# 1  [[-1, *], [0, 개방자치단체코드], [0, 관리번호], [0, 인허가일자]...
# 2  [[-1, *], [0, 개방자치단체코드], [0, 관리번호], [0, 인허가일자]...
# 3  [[-1, *], [0, 개방자치단체코드], [0, 관리번호], [0, 인허가일자]...
# 4  [[-1, *], [0, 연도], [0, 지역이름], [0, 주민등록인구], [0,...
#
#                                         column_types foreign_keys primary_keys
# 0  [text, number, number, time, number, text, tim...           []           []
# 1  [text, number, text, time, text, number, text,...           []           []
# 2  [text, number, text, time, time, number, text,...           []           []
# 3  [text, number, number, number, text, time, tim...           []           []
# 4  [text, time, text, number, number, number, num...           []           []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5121 entries, 0 to 139
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   source                 5121 non-null   object
#  1   db_id                  5121 non-null   object
#  2   table_names_original   5121 non-null   object
#  3   table_names            5121 non-null   object
#  4   column_names_original  5121 non-null   object
#  5   column_names           5121 non-null   object
#  6   column_types           5121 non-null   object
#  7   foreign_keys           5121 non-null   object
#  8   primary_keys           5121 non-null   object
# dtypes: object(9)
# memory usage: 400.1+ KB

# %%
#df.to_json('/content/drive/MyDrive/Project1/Data/Training/Tables/combined_data.json', orient='records')

# %%
def extract_indexes(df):
    """
    DataFrame에서 스키마 정보를 추출합니다.

    Args:
        df: 스키마 정보를 담고 있는 Pandas DataFrame.

    Returns:
        schema_info: 추출된 스키마 정보를 담은 리스트.
    """
    schema_info = []
    for index, row in df.iterrows():
        schema_info.append({
            "db_id": row['db_id'],
            "table_names_original": row['table_names_original'],
            "table_names": row['table_names'],
            "column_names_original": row['column_names_original'],
            "column_names": row['column_names'],
            "column_types": row['column_types'],
            "foreign_keys": row['foreign_keys'],
            "primary_keys": row['primary_keys']
        })
    return schema_info

# DataFrame에서 스키마 정보 추출
schema_info = extract_indexes(df)

# 추출된 정보 출력
for schema in schema_info:
    print(schema)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !pip install sentence-transformers
# !pip install faiss-cpu
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (3.2.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.44.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.6)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.5.0+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.24.7)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.8.30)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.10/dist-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from faiss-cpu) (24.1)
# Downloading faiss_cpu-1.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 73.4 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.9.0

# %%
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np

# 임베딩 모델 로드
model = SentenceTransformer('intfloat/multilingual-e5-large-instruct')

# 스키마 정보를 텍스트로 변환하여 임베딩 생성
schema_texts = [
    f"db_id: {table['db_id']}, "
    f"table_names_original: {table['table_names_original']}, "
    f"table_names: {table['table_names']}, "
    f"column_names_original: {', '.join(str(item) for item in table['column_names_original'])}, "
    f"column_names: {', '.join(str(item) for item in table['column_names'])}, "
    f"column_types: {', '.join(str(item) for item in table['column_types'])}, "
    f"foreign_keys: {table['foreign_keys']}, "
    f"primary_keys: {table['primary_keys']}"
    for table in schema_info
]
schema_embeddings = model.encode(schema_texts)

# FAISS 인덱스 생성 및 벡터 추가
dimension = schema_embeddings.shape[1]  # 임베딩 차원 수
index = faiss.IndexFlatL2(dimension)  # L2 거리 기반 인덱스 생성
index.add(np.array(schema_embeddings))  # 임베딩 추가

print("FAISS 인덱스에 스키마 정보 벡터화 및 저장 완료")
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/128 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/140k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/690 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.12G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/271 [00:00<?, ?B/s]
# FAISS 인덱스에 스키마 정보 벡터화 및 저장 완료

# %%
# 벡터 크기 확인 (모델의 벡터 크기: 1024차원)
print("벡터 크기:", schema_embeddings.shape)  # 결과: (5121, 1024)

# 첫 번째 문장의 벡터 일부 확인
print("첫 번째 문장의 벡터 값:", schema_embeddings[0][:10])  # 첫 10개 요소 출력
# Out:
# 벡터 크기: (5121, 1024)
# 첫 번째 문장의 벡터 값: [ 0.01257814  0.02321131 -0.03359962 -0.0291588   0.03624668 -0.03190263
#  -0.04739014  0.06126213  0.04956601  0.01573373]

# %%
# 사용자 질문 예시
query = "이름에 교통행정과가 들어가는 기관의 주소를 알려줘"
query_embedding = model.encode([query])

# FAISS 인덱스에서 유사한 스키마 검색
k = 5  # 상위 2개의 관련 결과를 검색
distances, indices = index.search(np.array(query_embedding), k)

print("가장 관련성이 높은 스키마 정보:")
for idx in indices[0]:
    print(schema_texts[idx])
# Out:
# 가장 관련성이 높은 스키마 정보:
# db_id: seouldata_transportation_1154, table_names_original: ['TB_ROAD_GPS_INFO'], table_names: ['서울시 도로위치인식표지 정보'], column_names_original: [-1, '*'], [0, 'BUSINAME'], [0, 'CONSTRAINTCAR'], [0, 'DIRECTIONNAME'], [0, 'LANDMARK'], [0, 'LIGHTCD'], [0, 'LINECOUNT'], [0, 'LINESTRUCT'], [0, 'LINETYPE'], [0, 'ORGANNAME'], [0, 'POLICEORG'], [0, 'POSITIONX'], [0, 'POSITIONY'], [0, 'ROADLINENAME'], [0, 'ROADPLACENAME'], [0, 'ROADWAYNAME'], [0, 'SECTIONMETER'], [0, 'SPEEDLIMIT'], [0, 'WORK_DTTM'], column_names: [-1, '*'], [0, '사업소이름'], [0, '제한차량'], [0, '도로위치방향'], [0, '도로세부내용'], [0, '시설물번호'], [0, '차로수'], [0, '도로구조'], [0, '선형'], [0, '관할구청'], [0, '관할경찰서'], [0, '위도'], [0, '경도'], [0, '노선명'], [0, '도로위치'], [0, '도로방향'], [0, '도로세부위치'], [0, '제한속도'], [0, '수집일'], column_types: text, text, text, text, text, text, text, text, text, text, text, number, number, text, text, text, text, text, time, foreign_keys: [], primary_keys: []
# db_id: publicdata_transportation_2860, table_names_original: ['MOIS_GUIDE_SHIP_OPERATOR'], table_names: ['행정안전부 유도선 사업자'], column_names_original: [-1, '*'], [0, 'NUMR'], [0, 'LICENSING_AGENCYS'], [0, 'MUTUALT'], [0, 'SORTATIONU'], [0, 'REPRESENTATIVE_NMV'], [0, 'ADDRESSW'], column_names: [-1, '*'], [0, '번호'], [0, '면허 신고기관'], [0, '상호'], [0, '구분'], [0, '성명 대표자'], [0, '주소'], column_types: text, number, text, text, text, text, text, foreign_keys: [], primary_keys: []
# db_id: publicdata_publicadministration_5474, table_names_original: ['C_STS_ADDRESS_LOCAL_GOV_FUNDED_INST_NATIONWIDE_MOIS'], table_names: ['행정안전부 전국 지방자치단체 출자출연기관 주소지 현황'], column_names_original: [-1, '*'], [0, 'SERIAL_NUMQ'], [0, 'ENGINE_TYPER'], [0, 'CITY_PROVINCES'], [0, 'C_C_C_D_ZZ'], [0, 'NM_ORGANIZATIONU'], [0, 'ADDRESSV'], [0, 'CONTACT_USW'], column_names: [-1, '*'], [0, '연번'], [0, '기관 종류'], [0, '시도'], [0, '시군구'], [0, '기관명'], [0, '주소'], [0, '연락처'], column_types: text, number, text, text, text, text, text, text, foreign_keys: [], primary_keys: []
# db_id: seouldata_transportation_966, table_names_original: ['OPRTLMTT_FCLTS_INFO'], table_names: ['서울시 운행제한시설물 위치정보'], column_names_original: [-1, '*'], [0, 'MANAGE_NO'], [0, 'DIV'], [0, 'MGC'], [0, 'FCLTY_NM'], [0, 'LC'], [0, 'START_X'], [0, 'START_Y'], [0, 'ARVL_X'], [0, 'ARVL_Y'], [0, 'TOT_WT'], [0, 'BT_LMTT'], [0, 'HG_LMTT'], [0, 'LT_LMTT'], [0, 'REAL_HG'], column_names: [-1, '*'], [0, '관리번호'], [0, '구분'], [0, '관리기관'], [0, '시설명'], [0, '위치'], [0, '출발 X'], [0, '출발 Y'], [0, '도착 X'], [0, '도착 Y'], [0, '총중량'], [0, '폭제한'], [0, '높이제한'], [0, '길이제한'], [0, '실제높이'], column_types: text, text, text, text, text, text, number, number, number, number, text, number, text, number, text, foreign_keys: [], primary_keys: []
# db_id: publicdata_transportation_2610, table_names_original: ['TF_STS_GNGH_WIDE_AREA_TF_INFO_SYS'], table_names: ['경상남도 김해시 광역교통정보시스템 교통 현황'], column_names_original: [-1, '*'], [0, 'ROAD_NUMU'], [0, 'ROAD_NMV'], [0, 'DIRECTIONW'], [0, 'STARTING_POINTX'], [0, 'LAST_POINTY'], [0, 'ZONE_LENGTHZ'], [0, 'START_POINT_CDA'], [0, 'END_POINT_CDB'], [0, 'AVG_SPEEDC'], [0, 'TRAFFIC_VOLUMED'], [0, 'TRAFFIC_CONDITIONSE'], [0, 'DT_TIMEF'], column_names: [-1, '*'], [0, '도로번호'], [0, '도로명'], [0, '방향'], [0, '시작지점'], [0, '끝지점'], [0, '구역길이'], [0, '시작지점코드'], [0, '끝지점코드'], [0, '평균속도'], [0, '통행량'], [0, '교통상황'], [0, '일시'], column_types: text, number, text, text, text, text, number, number, number, number, number, text, time, foreign_keys: [], primary_keys: []

# %%
# 사용자 질문 예시
query = "기관명과 주소를 알려줘"
query_embedding = model.encode([query])

# FAISS 인덱스에서 유사한 스키마 검색
k = 5  # 상위 2개의 관련 결과를 검색
distances, indices = index.search(np.array(query_embedding), k)

print("가장 관련성이 높은 스키마 정보:")
for idx in indices[0]:
    print(schema_texts[idx])
# Out:
# 가장 관련성이 높은 스키마 정보:
# db_id: publicdata_publicadministration_5474, table_names_original: ['C_STS_ADDRESS_LOCAL_GOV_FUNDED_INST_NATIONWIDE_MOIS'], table_names: ['행정안전부 전국 지방자치단체 출자출연기관 주소지 현황'], column_names_original: [-1, '*'], [0, 'SERIAL_NUMQ'], [0, 'ENGINE_TYPER'], [0, 'CITY_PROVINCES'], [0, 'C_C_C_D_ZZ'], [0, 'NM_ORGANIZATIONU'], [0, 'ADDRESSV'], [0, 'CONTACT_USW'], column_names: [-1, '*'], [0, '연번'], [0, '기관 종류'], [0, '시도'], [0, '시군구'], [0, '기관명'], [0, '주소'], [0, '연락처'], column_types: text, number, text, text, text, text, text, text, foreign_keys: [], primary_keys: []
# db_id: publicdata_welfare_5878, table_names_original: ['KYCI_N_YOUTH_COUNSELING_WELFARE_CNT'], table_names: ['한국청소년상담복지개발원 전국 청소년상담복지센터'], column_names_original: [-1, '*'], [0, 'CENTER_NMJ'], [0, 'AREAK'], [0, 'NM_BRANCHL'], [0, 'POSTAL_CDM'], [0, 'ADDRESSN'], [0, 'Y_C_P_G'], [0, 'A_P_C_H'], [0, 'FAX_MACHINEQ'], [0, 'HOMEPAGER'], column_names: [-1, '*'], [0, '센터명'], [0, '지역'], [0, '분소 이름'], [0, '우편번호'], [0, '주소'], [0, '1388 상담전화'], [0, '행정전화'], [0, '팩스'], [0, '홈페이지'], column_types: text, text, text, text, number, text, text, text, text, text, foreign_keys: [], primary_keys: []
# db_id: publicdata_climate_5039, table_names_original: ['STS_REG_BASIC_SAFE_H_EDU_INST_CONST_I_KOSHA'], table_names: ['한국산업안전보건공단 건설업기초안전보건교육기관 등록 현황'], column_names_original: [-1, '*'], [0, 'SERIAL_NUMG'], [0, 'I_C_F_L_O_DE'], [0, 'NM_EDUAL_INSTITUTIONI'], [0, 'PHONE_NUMJ'], [0, 'FAX_NUMK'], [0, 'POSTAL_CDL'], [0, 'ADDRESSM'], column_names: [-1, '*'], [0, '연번'], [0, '공단 일선 기관'], [0, '교육기관명'], [0, '전화번호'], [0, '팩스번호'], [0, '우편번호'], [0, '주소'], column_types: text, number, text, text, text, text, number, text, foreign_keys: [], primary_keys: []
# db_id: publicdata_healthcare_1413, table_names_original: ['STS_MEDICAL_INST_ESTABLISHED_MOHW_MEDICAL_INST_ETHICS_COMMITTEE'], table_names: ['보건복지부 의료기관윤리위원회 설치 의료기관 현황'], column_names_original: [-1, '*'], [0, 'ATTEMPT'], [0, 'TYPE'], [0, 'NAME_ORGANIZATION'], [0, 'PHONE_NUMBER'], [0, 'ADDRESS'], [0, 'LATITUDE'], [0, 'HARDNESS'], column_names: [-1, '*'], [0, '시도'], [0, '종별'], [0, '기관명'], [0, '전화번호'], [0, '주소'], [0, '위도'], [0, '경도'], column_types: text, text, text, text, text, text, number, number, foreign_keys: [], primary_keys: []
# db_id: seouldata_education_318, table_names_original: ['LIFETIME_EDU_ORGAN'], table_names: ['서울시 평생학습포털 평생교육기관 현황'], column_names_original: [-1, '*'], [0, 'DEPT_NM'], [0, 'TEL'], [0, 'ADDR'], [0, 'HOMEPAGE_URL'], [0, 'MAP_LAT'], [0, 'MAP_LNG'], column_names: [-1, '*'], [0, '기관명'], [0, '기관연락처'], [0, '기관주소'], [0, '홈페이지'], [0, '위치 위도'], [0, '위치 경도'], column_types: text, text, text, text, text, number, text, foreign_keys: [], primary_keys: []

# %%
# 사용자 질문 예시
query = "평생학습포털 평생교육기관 현황에서 강서문화원의 홈페이지 주소를 검색해 줄래"
query_embedding = model.encode([query])

# FAISS 인덱스에서 유사한 스키마 검색
k = 5  # 상위 2개의 관련 결과를 검색
distances, indices = index.search(np.array(query_embedding), k)

print("가장 관련성이 높은 스키마 정보:")
for idx in indices[0]:
    print(schema_texts[idx])
# Out:
# 가장 관련성이 높은 스키마 정보:
# db_id: seouldata_education_318, table_names_original: ['LIFETIME_EDU_ORGAN'], table_names: ['서울시 평생학습포털 평생교육기관 현황'], column_names_original: [-1, '*'], [0, 'DEPT_NM'], [0, 'TEL'], [0, 'ADDR'], [0, 'HOMEPAGE_URL'], [0, 'MAP_LAT'], [0, 'MAP_LNG'], column_names: [-1, '*'], [0, '기관명'], [0, '기관연락처'], [0, '기관주소'], [0, '홈페이지'], [0, '위치 위도'], [0, '위치 경도'], column_types: text, text, text, text, text, number, text, foreign_keys: [], primary_keys: []
# db_id: seouldata_education_321, table_names_original: ['OFFLINE_COURSE'], table_names: ['서울시 평생학습포털 오프라인강좌 정보'], column_names_original: [-1, '*'], [0, 'SITE_ID'], [0, 'ASP_ID'], [0, 'COURSE_ID'], [0, 'COURSE_GUBUN'], [0, 'COURSE_NM'], [0, 'COURSE_REQUEST_STR_DT'], [0, 'COURSE_REQUEST_END_DT'], [0, 'COURSE_STR_DT'], [0, 'COURSE_END_DT'], [0, 'COURSE_TARGET'], [0, 'CAPACITY'], [0, 'COURSE_APPLY_URL'], [0, 'INSERT_DT'], [0, 'UPDATE_DT'], column_names: [-1, '*'], [0, '사이트 아이디'], [0, 'ASP 아이디'], [0, '강의 아이디'], [0, '강의 구분'], [0, '강의 명'], [0, '수강신청 시작 일자'], [0, '수강신청 종료 일자'], [0, '강의 시작 일자'], [0, '강의 종료 일자'], [0, '강의대상'], [0, '정원'], [0, '수강신청 URL'], [0, '등록 일자'], [0, '수정 일자'], column_types: text, text, text, text, text, text, number, number, text, text, text, text, text, number, number, foreign_keys: [], primary_keys: []
# db_id: seouldata_culture_1169, table_names_original: ['SEOUL_SEONGDONG_WOMEN_RESOURCES_CLASS'], table_names: ['서울시 성동여성인력개발센터 교육강좌 정보'], column_names_original: [-1, '*'], [0, 'CLASS_CODE'], [0, 'CLASS_NAME'], [0, 'ORGAN_CODE'], [0, 'ORGAN_NAME'], [0, 'DIFFICULTY_NAME'], [0, 'RECEIVE_TIME_TO'], [0, 'EDUCATE_FROM'], [0, 'EDUCATE_TO'], [0, 'EDUCATE_TIME_TO'], [0, 'MONDAY'], [0, 'TUESDAY'], [0, 'WEDNESDAY'], [0, 'SATURDAY'], [0, 'COLLECT_NUM'], [0, 'SPARE_NUM'], [0, 'EDUCATE_FEE'], [0, 'VISIT_RECEIVE_FLAG'], column_names: [-1, '*'], [0, '강좌코드'], [0, '강좌명'], [0, '기관코드'], [0, '기관명'], [0, '난이도명'], [0, '수강신청 접수마감시간'], [0, '교육시작일'], [0, '교육종료일'], [0, '교육종료시간'], [0, '교육요일 월'], [0, '교육요일 화'], [0, '교육요일 수'], [0, '교육요일 토'], [0, '모집정원'], [0, '예비자모집인원'], [0, '수강료 원'], [0, '접수방법 방문접수여부Y N'], column_types: text, text, text, number, text, text, text, time, time, text, text, text, text, text, number, text, text, text, foreign_keys: [], primary_keys: []
# db_id: seouldata_education_1269, table_names_original: ['NEIS_ACADEMY_INFO_GS'], table_names: ['서울시 강서구 학원 교습소정보'], column_names_original: [-1, '*'], [0, 'ADMST_ZONE_NM'], [0, 'ACA_INSTI_SC_NM'], [0, 'ACA_NM'], [0, 'ESTBL_YMD'], [0, 'REG_YMD'], [0, 'TOFOR_SMTOT'], [0, 'DTM_RCPTN_ABLTY_NMPR_SMTOT'], [0, 'REALM_SC_NM'], [0, 'LE_ORD_NM'], [0, 'LE_CRSE_NM'], [0, 'PSNBY_THCC_CNTNT'], [0, 'THCC_OTHBC_YN'], [0, 'BRHS_ACA_YN'], [0, 'FA_RDNZC'], [0, 'FA_RDNMA'], [0, 'FA_RDNDA'], [0, 'LOAD_DTM'], column_names: [-1, '*'], [0, '행정구역명'], [0, '학원교습소명'], [0, '학원명'], [0, '개설일자'], [0, '등록일자'], [0, '정원합계'], [0, '일시수용능력인원합계'], [0, '분야명'], [0, '교습계열명'], [0, '교습과정명'], [0, '인당수강료내용'], [0, '수강료공개여부'], [0, '기숙사학원여부'], [0, '도로명우편번호'], [0, '도로명주소'], [0, '도로명상세주소'], [0, '적재일시'], column_types: text, text, text, text, time, time, text, text, text, text, text, text, text, text, number, text, text, time, foreign_keys: [], primary_keys: []
# db_id: seouldata_culture_1175, table_names_original: ['SEOUL_SEOCHO_WOMEN_RESOURCES_CLASS'], table_names: ['서울시 서초여성인력개발센터 교육강좌 정보'], column_names_original: [-1, '*'], [0, 'CLASS_CODE'], [0, 'CLASS_NAME'], [0, 'ORGAN_CODE'], [0, 'ORGAN_NAME'], [0, 'DIFFICULTY'], [0, 'DIFFICULTY_NAME'], [0, 'RECEIVE_FROM'], [0, 'RECEIVE_TO'], [0, 'RECEIVE_TIME_FROM'], [0, 'RECEIVE_TIME_TO'], [0, 'EDUCATE_FROM'], [0, 'EDUCATE_TO'], [0, 'EDUCATE_TIME_FROM'], [0, 'EDUCATE_TIME_TO'], [0, 'TUESDAY'], [0, 'WEDNESDAY'], [0, 'THURSDAY'], [0, 'FRIDAY'], [0, 'SATURDAY'], [0, 'COLLECT_NUM'], [0, 'SPARE_NUM'], [0, 'EDUCATE_FEE'], [0, 'VISIT_RECEIVE_FLAG'], [0, 'ONLINE_RECEIVE_FLAG'], [0, 'URL'], column_names: [-1, '*'], [0, '강좌코드'], [0, '강좌명'], [0, '기관코드'], [0, '기관명'], [0, '난이도코드'], [0, '난이도명'], [0, '수강신청 접수시작일'], [0, '수강신청 접수종료일'], [0, '수강신청 접수시작시간'], [0, '수강신청 접수마감시간'], [0, '교육시작일'], [0, '교육종료일'], [0, '교육시작시간'], [0, '교육종료시간'], [0, '교육요일 화'], [0, '교육요일 수'], [0, '교육요일 목'], [0, '교육요일 금'], [0, '교육요일 토'], [0, '모집정원'], [0, '예비자모집인원'], [0, '수강료 원'], [0, '접수방법 방문접수여부Y N'], [0, '접수방법 온라인접수여부Y N'], [0, '상세정보 주소'], column_types: text, text, text, number, text, text, text, time, time, text, text, time, time, text, text, text, text, text, text, text, number, text, text, text, text, text, foreign_keys: [], primary_keys: []

# %%
# 사용자 질문 예시
query = "서울시 미래 청년 기획단의 기관 주소를 찾아줘"
query_embedding = model.encode([query])

# FAISS 인덱스에서 유사한 스키마 검색
k = 5  # 상위 2개의 관련 결과를 검색
distances, indices = index.search(np.array(query_embedding), k)

print("가장 관련성이 높은 스키마 정보:")
for idx in indices[0]:
    print(schema_texts[idx])
# Out:
# 가장 관련성이 높은 스키마 정보:
# db_id: seouldata_industrialeconomic_968, table_names_original: ['S_E_DESIGNATION'], table_names: ['서울시 사회적기업 예비 지정 현황'], column_names_original: [-1, '*'], [0, 'COMPANYSEQ'], [0, 'TARGETNUM'], [0, 'COMPANYNM'], [0, 'WORKCONTENT'], [0, 'ADDRESS'], [0, 'PHONE'], column_names: [-1, '*'], [0, '업체일련번호'], [0, '지정번호'], [0, '회사명'], [0, '사업내용'], [0, '주소'], [0, '연락처'], column_types: text, number, text, text, text, text, text, foreign_keys: [], primary_keys: []
# db_id: seouldata_culture_861, table_names_original: ['FUTURE_COURSE_INFO'], table_names: ['서울시 서울미래유산 체험코스 정보'], column_names_original: [-1, '*'], [0, 'AC_IDX'], [0, 'HT_THUMB_NAM'], [0, 'AC_TITLE'], [0, 'AC_RECO_COUNT'], [0, 'AC_READ_COUNT'], [0, 'AC_CREATED'], [0, 'AC_TAKE_TIME'], [0, 'ACI_ORDER'], [0, 'HT_NM'], [0, 'ACI_LAT'], [0, 'ACI_LONG'], [0, 'HT_NEW_ADDR'], [0, 'ACP_THUMB_NAME'], column_names: [-1, '*'], [0, '체험코스 아이디'], [0, '체험코스 썸네일 경로'], [0, '체험코스 제목'], [0, '좋아요 수'], [0, '조회 수'], [0, '등록일자'], [0, '체험코스 시간'], [0, '해당 미래유산의 체험순서'], [0, '미래유산명'], [0, 'X 좌표'], [0, 'Y 좌표'], [0, '미래유산 소재지'], [0, '미래유산 썸네일 경로'], column_types: text, number, text, text, text, number, time, text, text, text, number, number, text, text, foreign_keys: [], primary_keys: []
# db_id: seouldata_education_318, table_names_original: ['LIFETIME_EDU_ORGAN'], table_names: ['서울시 평생학습포털 평생교육기관 현황'], column_names_original: [-1, '*'], [0, 'DEPT_NM'], [0, 'TEL'], [0, 'ADDR'], [0, 'HOMEPAGE_URL'], [0, 'MAP_LAT'], [0, 'MAP_LNG'], column_names: [-1, '*'], [0, '기관명'], [0, '기관연락처'], [0, '기관주소'], [0, '홈페이지'], [0, '위치 위도'], [0, '위치 경도'], column_types: text, text, text, text, text, number, text, foreign_keys: [], primary_keys: []
# db_id: seouldata_industrialeconomic_443, table_names_original: ['V_NTCN_NGC001'], table_names: ['서울도시농업 학습과 체험의 배우러 가기 정보'], column_names_original: [-1, '*'], [0, 'ATDRC_CODE'], [0, 'SJ'], [0, 'REQST_BGNDE'], [0, 'REQST_ENDDE'], [0, 'USE_BGNDE'], [0, 'RCRIT_NMPR'], [0, 'ONSLF_REQST_AT'], [0, 'LINK'], [0, 'CHRGE'], [0, 'CN'], [0, 'RDNMADR'], [0, 'LA'], [0, 'LO'], [0, 'ATPN'], [0, 'REFRNC'], column_names: [-1, '*'], [0, '등록자치구'], [0, '과정명'], [0, '신청시작일'], [0, '신청종료일'], [0, '이용시작일'], [0, '모집인원 수량'], [0, '신청방법'], [0, '신청링크'], [0, '이용요금'], [0, '세부사항'], [0, '주소'], [0, '위도'], [0, '경도'], [0, '주의사항'], [0, '문의처'], column_types: text, text, text, time, time, time, text, text, text, text, text, text, text, text, text, text, foreign_keys: [], primary_keys: []
# db_id: publicdata_welfare_5878, table_names_original: ['KYCI_N_YOUTH_COUNSELING_WELFARE_CNT'], table_names: ['한국청소년상담복지개발원 전국 청소년상담복지센터'], column_names_original: [-1, '*'], [0, 'CENTER_NMJ'], [0, 'AREAK'], [0, 'NM_BRANCHL'], [0, 'POSTAL_CDM'], [0, 'ADDRESSN'], [0, 'Y_C_P_G'], [0, 'A_P_C_H'], [0, 'FAX_MACHINEQ'], [0, 'HOMEPAGER'], column_names: [-1, '*'], [0, '센터명'], [0, '지역'], [0, '분소 이름'], [0, '우편번호'], [0, '주소'], [0, '1388 상담전화'], [0, '행정전화'], [0, '팩스'], [0, '홈페이지'], column_types: text, text, text, text, number, text, text, text, text, text, foreign_keys: [], primary_keys: []

# %%
def merge_json_files_to_dataframe(root_dir):
    """
    Merges all JSON files in subfolders of the root directory into a single DataFrame.

    Args:
        root_dir: The path to the root directory.

    Returns:
        A Pandas DataFrame containing the merged data.
    """
    df = pd.DataFrame()  # Create DataFrame

    for dirpath, dirnames, filenames in os.walk(root_dir):
        for filename in filenames:
            if filename.endswith('.json'):
                filepath = os.path.join(dirpath, filename)
                print(filepath)
                with open(filepath, 'r', encoding='utf-8') as f:
                    try:
                        data = json.load(f)
                        df_temp = pd.DataFrame(data["data"])
                        df = pd.concat([df, df_temp])
                    except json.JSONDecodeError as e:
                        print(f"Error decoding JSON in file: {filepath}")
                        print(f"Error message: {e}")

    return df

# %%
# 구글 드라이브 폴더 경로를 지정합니다.
folder_path = '/content/drive/MyDrive/Project1/Data/Training/SQLs'

# JSON 파일을 읽어와 병합합니다.
df2 = merge_json_files_to_dataframe(folder_path)

# 병합된 DataFrame을 출력합니다.
print(df2.info())
# Out:
# /content/drive/MyDrive/Project1/Data/Training/SQLs/2. 공공데이터포털/01. 보건/TEXT_NL2SQL_label_publicdata_healthcare.json
# /content/drive/MyDrive/Project1/Data/Training/SQLs/2. 공공데이터포털/03. 문화／관광/TEXT_NL2SQL_label_publicdata_culture.json
# /content/drive/MyDrive/Project1/Data/Training/SQLs/2. 공공데이터포털/08. 교육/TEXT_NL2SQL_label_publicdata_education.json
# /content/drive/MyDrive/Project1/Data/Training/SQLs/2. 공공데이터포털/06. 환경/TEXT_NL2SQL_label_publicdata_climate.json
# /content/drive/MyDrive/Project1/Data/Training/SQLs/2. 공공데이터포털/02. 일반행정/TEXT_NL2SQL_label_publicdata_publicadministration.json
# /content/drive/MyDrive/Project1/Data/Training/SQLs/2. 공공데이터포털/04. 산업／경제/TEXT_NL2SQL_label_publicdata_industrialeconomic.json
# /content/drive/MyDrive/Project1/Data/Training/SQLs/2. 공공데이터포털/05. 복지/TEXT_NL2SQL_label_publicdata_welfare.json
# /content/drive/MyDrive/Project1/Data/Training/SQLs/2. 공공데이터포털/07. 교통/TEXT_NL2SQL_label_publicdata_transportation.json
# /content/drive/MyDrive/Project1/Data/Training/SQLs/1. 서울_열린데이터/07. 교통/TEXT_NL2SQL_label_seouldata_transportation.json
# /content/drive/MyDrive/Project1/Data/Training/SQLs/1. 서울_열린데이터/01. 보건/TEXT_NL2SQL_label_seouldata_healthcare.json
# /content/drive/MyDrive/Project1/Data/Training/SQLs/1. 서울_열린데이터/02. 일반행정/TEXT_NL2SQL_label_seouldata_publicadministration.json
# /content/drive/MyDrive/Project1/Data/Training/SQLs/1. 서울_열린데이터/03. 문화／관광/TEXT_NL2SQL_label_seouldata_culture.json
# /content/drive/MyDrive/Project1/Data/Training/SQLs/1. 서울_열린데이터/04. 산업／경제/TEXT_NL2SQL_label_seouldata_industrialeconomic.json
# /content/drive/MyDrive/Project1/Data/Training/SQLs/1. 서울_열린데이터/08. 교육/TEXT_NL2SQL_label_seouldata_education.json
# /content/drive/MyDrive/Project1/Data/Training/SQLs/1. 서울_열린데이터/05. 복지/TEXT_NL2SQL_label_seouldata_welfare.json
# /content/drive/MyDrive/Project1/Data/Training/SQLs/1. 서울_열린데이터/06. 환경/TEXT_NL2SQL_label_seouldata_climate.json
# /content/drive/MyDrive/Project1/Data/Training/SQLs/3. 빅데이터캠퍼스/02. 일반행정/TEXT_NL2SQL_label_seoulpopulation_publicadministration.json
# <class 'pandas.core.frame.DataFrame'>
# Index: 88946 entries, 0 to 310
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   db_id           88946 non-null  object
#  1   utterance_id    88946 non-null  object
#  2   hardness        88946 non-null  object
#  3   utterance_type  88946 non-null  object
#  4   query           88946 non-null  object
#  5   utterance       88946 non-null  object
#  6   values          88946 non-null  object
#  7   cols            88946 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB
# None

# %%
df2 = df2.dropna(subset=['query'])

df2.info()
df2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 88946 entries, 0 to 310
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   db_id           88946 non-null  object
#  1   utterance_id    88946 non-null  object
#  2   hardness        88946 non-null  object
#  3   utterance_type  88946 non-null  object
#  4   query           88946 non-null  object
#  5   utterance       88946 non-null  object
#  6   values          88946 non-null  object
#  7   cols            88946 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB
#                         db_id utterance_id hardness utterance_type  \
# 0  publicdata_healthcare_1812     Wht_9888   medium           BR04
# 1  publicdata_healthcare_1812    Whr_12275     hard           BR03
# 2  publicdata_healthcare_1812     Wht_9889     easy           BR04
# 3  publicdata_healthcare_1812    Whr_12276     easy           BR03
# 4  publicdata_healthcare_1812    Whr_12277     easy           BR03
#
#                                                query  \
# 0  SELECT DISTINCT CONTACT FROM FOOD_RELATED_INDU...
# 1  SELECT LATITUDE, HARDNESS FROM FOOD_RELATED_IN...
# 2  SELECT INDUSTRY_NAME FROM FOOD_RELATED_INDUSTR...
# 3  SELECT DISTINCT MATERIAL_MAP_NAME FROM FOOD_RE...
# 4  SELECT HARDNESS FROM FOOD_RELATED_INDUSTRIES_Y...
#
#                                         utterance  \
# 0          소재지 도로명에 무내미길이 들어가는 업소의 연락처를 중복 없이 보여줘
# 1  소재지 도로명 지평면이 들어가며 업소명에 회사가 포함되는 곳의 위도와 경도를 알려줘
# 2                          이름이 알이네장터인 업소의 업종명은 뭐야
# 3                        라라마트의 소재지 도로명을 중복 없이 보여줘
# 4                   연락처가 031-772-0189인 곳의 경도를 찾아줘
#
#                                               values  \
# 0                                                 []
# 1  [{'token': '지평면', 'start': 8, 'column_index': ...
# 2  [{'token': '알이네장터', 'start': 4, 'column_index'...
# 3  [{'token': '라라마트', 'start': 0, 'column_index':...
# 4  [{'token': '031-772-0189', 'start': 5, 'column...
#
#                                                 cols
# 0  [{'token': '연락처', 'start': 24, 'column_index':...
# 1  [{'token': '경도', 'start': 39, 'column_index': ...
# 2  [{'token': '업종명', 'start': 15, 'column_index':...
# 3  [{'token': '소재지 도로명', 'start': 6, 'column_inde...
# 4  [{'token': '경도', 'start': 22, 'column_index': 5}]

# %%
def check_db(query, db_id, n):
  query_embedding = model.encode([query])

  # FAISS 인덱스에서 유사한 스키마 검색
  k = n  # 상위 n개의 관련 결과를 검색
  distances, indices = index.search(np.array(query_embedding), k)

  for idx in indices[0]:
      if db_id in schema_texts[idx]:
          return True

  return False

# %%
# prompt: df2에서 db_id와 utterance 컬럼의 값들을 리스트 쌍으로 가져오는 코드를 작성해주세요

db_utterance_pairs = list(zip(df2['db_id'].tolist(), df2['utterance'].tolist()))

print(db_utterance_pairs[0])
# Out:
# ('publicdata_healthcare_1812', '소재지 도로명에 무내미길이 들어가는 업소의 연락처를 중복 없이 보여줘')

# %%
# k = 1

count_all = 0
count_true = 0
count_false = 0

for q in db_utterance_pairs:
  if check_db(q[1], q[0], 1) == True:
    count_true += 1
  else:
    count_false += 1
  count_all += 1

print(count_all)
print(count_true)
print(count_false)
# Out:
# 88946
# 21602
# 67344
# '\nmodel : intfloat/multilingual-e5-large-instruct (k=1)\n\n88946\n21602\n67344\n'

# %%
# k = 5

count_all = 0
count_true = 0
count_false = 0

for q in db_utterance_pairs:
  if check_db(q[1], q[0], 5) == True:
    count_true += 1
  else:
    count_false += 1
  count_all += 1

print(count_all)
print(count_true)
print(count_false)
# Out:
# 88946
# 36460
# 52486
