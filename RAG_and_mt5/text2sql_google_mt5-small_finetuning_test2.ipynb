# %% [markdown]
# ## 1. 데이터 로드

# %% [markdown]
# 1-1. DB Schema 정보 불러오기

# %%
import os
from google.colab import drive
drive.mount('/content/drive') # 구글 드라이브 마운트
# Out:
# Mounted at /content/drive

# %%
import json
import pandas as pd

# %%
dir_val = '/content/drive/MyDrive/Project1/Data/Validation/Tables' # Vaildation Data Set의 DB Schema 정보가 있는 폴더 경로 지정
files = os.listdir(dir_val)

# %%
def extract_indexes(df):
    """
    DataFrame에서 스키마 정보를 추출합니다.

    Args:
        df: 스키마 정보를 담고 있는 Pandas DataFrame.

    Returns:
        schema_info: 추출된 스키마 정보를 담은 리스트.
    """
    schema_info = []
    for index, row in df.iterrows():
        schema_info.append({
            "db_id": row['db_id'],
            "table_names_original": row['table_names_original'],
            "column_names_original": row['column_names_original'],
            "column_types": row['column_types']
        })
    return schema_info

# %%
df_val = pd.DataFrame()

for filename in os.listdir(dir_val):
  if filename.endswith('.json'):
    filepath = os.path.join(dir_val, filename)
    with open(filepath, 'r') as f:
      data = json.load(f)
      df_temp = pd.DataFrame(data["data"])
      df_val = pd.concat([df_val, df_temp])

# %%
df_val.head()
# Out:
#   source                      db_id            table_names_original  \
# 0  서울특별시   seouldata_healthcare_733      [TB_PHARMACY_OPERATE_INFO]
# 1  서울특별시  seouldata_healthcare_1353  [L_O_C_A_L_D_A_T_A_020302_D_D]
# 2  서울특별시  seouldata_healthcare_1485  [L_O_C_A_L_D_A_T_A_020302_M_P]
# 3  서울특별시  seouldata_healthcare_2398         [YS_FOOD_COLLECT_CHECK]
# 4  서울특별시  seouldata_healthcare_2088  [L_O_C_A_L_D_A_T_A_072211_J_G]
#
#                table_names                              column_names_original  \
# 0         [서울시 약국 운영시간 정보]  [[-1, *], [0, HPID], [0, DUTYADDR], [0, DUTYNA...
# 1   [서울시 동대문구 동물약국 인허가 정보]  [[-1, *], [0, OPNSFTEAMCODE], [0, MGTNO], [0, ...
# 2    [서울시 마포구 동물약국 인허가 정보]  [[-1, *], [0, OPNSFTEAMCODE], [0, MGTNO], [0, ...
# 3   [서울시 용산구 전체 식품수거검사 현황]  [[-1, *], [0, CGG_CODE], [0, SNT_COB_CODE], [0...
# 4  [서울시 중구 식품제조가공업 인허가 정보]  [[-1, *], [0, OPNSFTEAMCODE], [0, MGTNO], [0, ...
#
#                                         column_names  \
# 0  [[-1, *], [0, 약국아이디], [0, 주소], [0, 약국명], [0, 대...
# 1  [[-1, *], [0, 개방자치단체코드], [0, 관리번호], [0, 인허가일자]...
# 2  [[-1, *], [0, 개방자치단체코드], [0, 관리번호], [0, 인허가일자]...
# 3  [[-1, *], [0, 시군구코드], [0, 업종코드], [0, 업종명], [0,...
# 4  [[-1, *], [0, 개방자치단체코드], [0, 관리번호], [0, 인허가취소일...
#
#                                         column_types foreign_keys primary_keys
# 0  [text, text, text, text, text, number, number,...           []           []
# 1  [text, number, number, time, number, text, num...           []           []
# 2  [text, number, number, time, text, text, numbe...           []           []
# 3  [text, number, number, text, number, text, tex...           []           []
# 4  [text, number, text, text, text, number, text,...           []           []

# %%
# DataFrame에서 스키마 정보 추출
schema_val_info = extract_indexes(df_val)

# 추출된 정보 출력
for schema in schema_val_info:
    print(schema)
# Out:
# {'db_id': 'seouldata_healthcare_733', 'table_names_original': ['TB_PHARMACY_OPERATE_INFO'], 'column_names_original': [[-1, '*'], [0, 'HPID'], [0, 'DUTYADDR'], [0, 'DUTYNAME'], [0, 'DUTYTEL1'], [0, 'DUTYTIME1C'], [0, 'DUTYTIME2C'], [0, 'DUTYTIME3C'], [0, 'DUTYTIME4C'], [0, 'DUTYTIME5C'], [0, 'DUTYTIME6C'], [0, 'DUTYTIME7C'], [0, 'DUTYTIME8C'], [0, 'DUTYTIME1S'], [0, 'DUTYTIME2S'], [0, 'DUTYTIME3S'], [0, 'DUTYTIME4S'], [0, 'DUTYTIME5S'], [0, 'DUTYTIME6S'], [0, 'DUTYTIME7S'], [0, 'DUTYTIME8S'], [0, 'POSTCDN1'], [0, 'POSTCDN2'], [0, 'WGS84LON'], [0, 'WGS84LAT'], [0, 'WORK_DTTM']], 'column_types': ['text', 'text', 'text', 'text', 'text', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'time']}
# {'db_id': 'seouldata_healthcare_1353', 'table_names_original': ['L_O_C_A_L_D_A_T_A_020302_D_D'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'TRDSTATEGBN'], [0, 'TRDSTATENM'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'SITETEL'], [0, 'SITEAREA'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEGBN'], [0, 'UPDATEDT'], [0, 'UPTAENM'], [0, 'X'], [0, 'Y'], [0, 'RGTMBDSNO']], 'column_types': ['text', 'number', 'number', 'time', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_1485', 'table_names_original': ['L_O_C_A_L_D_A_T_A_020302_M_P'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'APVCANCELYMD'], [0, 'TRDSTATENM'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'CLGSTDT'], [0, 'CLGENDDT'], [0, 'SITEAREA'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEGBN'], [0, 'UPDATEDT'], [0, 'X'], [0, 'Y'], [0, 'LINDJOBGBNNM'], [0, 'LINDPRCBGBNNM'], [0, 'LINDSEQNO'], [0, 'RGTMBDSNO'], [0, 'TOTEPNUM']], 'column_types': ['text', 'number', 'number', 'time', 'text', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'number', 'text']}
# {'db_id': 'seouldata_healthcare_2398', 'table_names_original': ['YS_FOOD_COLLECT_CHECK'], 'column_names_original': [[-1, '*'], [0, 'CGG_CODE'], [0, 'SNT_COB_CODE'], [0, 'SNT_COB_NM'], [0, 'PLN_SE_CODE'], [0, 'PLN_SE_NM'], [0, 'CHK_PLN_NM'], [0, 'COL_PLN_NM'], [0, 'COL_WHY_CODE'], [0, 'UPSO_NM'], [0, 'ATCL_GUN_NM'], [0, 'ATCL_NM'], [0, 'PRDT_NM'], [0, 'EDF_NM'], [0, 'RM_NM'], [0, 'PDT_UPSO_NM'], [0, 'COL_YMD'], [0, 'COL_QUA'], [0, 'PRDT_SIZE'], [0, 'LOT_NO'], [0, 'PRDT_YUTONG_DLN'], [0, 'YUTONG_DLN_PRD_YMD_FROM'], [0, 'DEPO_STATE_CODE'], [0, 'BCE_CODE'], [0, 'CHD_SMBL_FD_KD_CODE'], [0, 'FACTORY_NM'], [0, 'NTN'], [0, 'ISP_SE'], [0, 'ISP_REQ_YMD'], [0, 'ISP_RT_REPLY_YMD'], [0, 'COL_ISP_RT_GBN'], [0, 'COL_ISP_SE'], [0, 'COL_PLC_SE'], [0, 'COL_PDT_DEAL'], [0, 'GNT_NO']], 'column_types': ['text', 'number', 'number', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'time', 'number', 'text', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'time', 'time', 'text', 'text', 'text', 'text', 'number']}
# {'db_id': 'seouldata_healthcare_2088', 'table_names_original': ['L_O_C_A_L_D_A_T_A_072211_J_G'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVCANCELYMD'], [0, 'TRDSTATENM'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'CLGSTDT'], [0, 'CLGENDDT'], [0, 'ROPNYMD'], [0, 'SITETEL'], [0, 'SITEAREA'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEGBN'], [0, 'UPTAENM'], [0, 'Y'], [0, 'MANEIPCNT'], [0, 'WMEIPCNT'], [0, 'TRDPJUBNSENM'], [0, 'LVSENM'], [0, 'WTRSPLYFACILSENM'], [0, 'TOTEPNUM'], [0, 'HOFFEPCNT'], [0, 'FCTYOWKEPCNT'], [0, 'FCTYSILJOBEPCNT'], [0, 'MULTUSNUPSOYN'], [0, 'FACILTOTSCP'], [0, 'JTUPSOASGNNO'], [0, 'JTUPSOMAINEDF'], [0, 'HOMEPAGE']], 'column_types': ['text', 'number', 'text', 'text', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'number', 'number', 'text', 'text', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_2459', 'table_names_original': ['SB_PUBLIC_HYGIENE_BIZ_PUBLIC_USE_FACILITY'], 'column_names_original': [[-1, '*'], [0, 'CGG_CODE'], [0, 'SNT_COB_CODE'], [0, 'YY'], [0, 'UPSO_SNO'], [0, 'UPSO_GSL_YMD'], [0, 'UPSO_NM'], [0, 'BMAN_STDT'], [0, 'BUP_NM'], [0, 'SITE_STDT'], [0, 'ADMDNG_NM'], [0, 'DCB_YMD'], [0, 'SNT_UPTAE_NM'], [0, 'ED_FIN_YMD'], [0, 'YANGSIL'], [0, 'CHAIR_NUM'], [0, 'BALHANSIL_YN'], [0, 'WASHMC_NUM'], [0, 'PERM_NT_NO'], [0, 'KOR_FRGNR_GBN'], [0, 'NTN']], 'column_types': ['text', 'number', 'number', 'number', 'number', 'time', 'text', 'time', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_2654', 'table_names_original': ['GD_ADMIN_MESURE_PUBLIC'], 'column_names_original': [[-1, '*'], [0, 'CGG_CODE'], [0, 'ADM_DISPO_YMD'], [0, 'GNT_NO'], [0, 'SNT_COB_NM'], [0, 'SNT_UPTAE_NM'], [0, 'UPSO_NM'], [0, 'SITE_ADDR_RD'], [0, 'SITE_ADDR'], [0, 'DRT_INSP_YMD'], [0, 'ADMM_STATE'], [0, 'DISPO_CTN'], [0, 'BAS_LAW'], [0, 'VIOR_YMD'], [0, 'DISPO_CTN_DT'], [0, 'DISPO_GIGAN'], [0, 'INSP_GBN_CODE'], [0, 'TRDP_AREA']], 'column_types': ['text', 'number', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'time', 'text', 'text', 'text', 'time', 'text', 'text', 'text', 'number']}
# {'db_id': 'seouldata_healthcare_2677', 'table_names_original': ['SC_MODEL_RESTAURANT_DESIGNATE'], 'column_names_original': [[-1, '*'], [0, 'SC_RESTAURANT_CGG_CODE'], [0, 'ASGN_YY'], [0, 'SC_RESTAURANT_ASGN_SNO'], [0, 'SC_RESTAURANT_APPL_YMD'], [0, 'UPSO_NM'], [0, 'SC_RESTAURANT_SITE_ADDR_RD'], [0, 'SC_RESTAURANT_SITE_ADDR'], [0, 'SC_RESTAURANT_PERM_NT_NO'], [0, 'SNT_UPTAE_NM'], [0, 'MAIN_EDF'], [0, 'TRDP_AREA'], [0, 'ADMDNG_NM'], [0, 'UPSO_SITE_TELNO']], 'column_types': ['text', 'number', 'time', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_3349', 'table_names_original': ['L_O_C_A_L_D_A_T_A_072206_S_P'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'APVCANCELYMD'], [0, 'TRDSTATEGBN'], [0, 'TRDSTATENM'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'CLGSTDT'], [0, 'CLGENDDT'], [0, 'ROPNYMD'], [0, 'SITETEL'], [0, 'SITEAREA'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEGBN'], [0, 'UPDATEDT'], [0, 'UPTAENM'], [0, 'Y'], [0, 'LINDJOBGBNNM'], [0, 'LINDPRCBGBNNM'], [0, 'LINDSEQNO']], 'column_types': ['text', 'number', 'number', 'time', 'text', 'number', 'text', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_4595', 'table_names_original': ['L_O_C_A_L_D_A_T_A_010202_G_D'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'APVCANCELYMD'], [0, 'TRDSTATEGBN'], [0, 'TRDSTATENM'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'CLGENDDT'], [0, 'ROPNYMD'], [0, 'SITEAREA'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEGBN'], [0, 'UPDATEDT'], [0, 'UPTAENM'], [0, 'X'], [0, 'Y'], [0, 'MEDKIND'], [0, 'SJYN'], [0, 'TOTSCP'], [0, 'TRDSCP']], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_397', 'table_names_original': ['L_O_C_A_L_D_A_T_A_010108'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'APVCANCELYMD'], [0, 'TRDSTATENM'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'CLGSTDT'], [0, 'SITETEL'], [0, 'SITEAREA'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'UPDATEGBN'], [0, 'UPDATEDT'], [0, 'UPTAENM'], [0, 'X'], [0, 'Y'], [0, 'METRORGASSRNM'], [0, 'HSTRMNUM'], [0, 'SICBNUM'], [0, 'TOTAR'], [0, 'MEDEXTRITEMSCN'], [0, 'ASGNCANCELYMD'], [0, 'MITMDCDEPNM'], [0, 'EMERCARSPEC'], [0, 'EMERCARGEN'], [0, 'TOTEPNUM'], [0, 'RESCNT']], 'column_types': ['text', 'number', 'text', 'time', 'text', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_876', 'table_names_original': ['L_O_C_A_L_D_A_T_A_072401'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'APVCANCELYMD'], [0, 'TRDSTATENM'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'CLGENDDT'], [0, 'ROPNYMD'], [0, 'SITETEL'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEGBN'], [0, 'UPDATEDT'], [0, 'X'], [0, 'Y'], [0, 'CULWRKRSENM'], [0, 'REGNSENM'], [0, 'NEARENVNM'], [0, 'INSURORGNM'], [0, 'BDNGSRVNM'], [0, 'STROOMCNT'], [0, 'CNSTYAREA'], [0, 'ENGSTNTRNMNM'], [0, 'SHPCNT'], [0, 'SHPINFO']], 'column_types': ['text', 'number', 'text', 'time', 'time', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_1768', 'table_names_original': ['L_O_C_A_L_D_A_T_A_010105_G_J'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'APVCANCELYMD'], [0, 'TRDSTATENM'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'CLGSTDT'], [0, 'ROPNYMD'], [0, 'SITETEL'], [0, 'SITEAREA'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEGBN'], [0, 'UPDATEDT'], [0, 'X'], [0, 'Y']], 'column_types': ['text', 'number', 'text', 'time', 'time', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_1365', 'table_names_original': ['L_O_C_A_L_D_A_T_A_010102_G_S'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'TRDSTATENM'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'CLGSTDT'], [0, 'CLGENDDT'], [0, 'SITETEL'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEDT'], [0, 'UPTAENM'], [0, 'X'], [0, 'Y'], [0, 'METRPNUM'], [0, 'HSTRMNUM'], [0, 'SICBNUM'], [0, 'TOTAR'], [0, 'MEDEXTRITEMSCN'], [0, 'MEDEXTRITEMSCNNM'], [0, 'MITMDCASGNTYPE'], [0, 'TOTEPNUM'], [0, 'RESCNT'], [0, 'PMTBEDNUM'], [0, 'FRSTASGNYMD']], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'text', 'time', 'time', 'time', 'text', 'number', 'text', 'text', 'text', 'number', 'time', 'text', 'number', 'number', 'text', 'text', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_2286', 'table_names_original': ['L_O_C_A_L_D_A_T_A_072219_Y_D'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'APVCANCELYMD'], [0, 'TRDSTATEGBN'], [0, 'TRDSTATENM'], [0, 'DTLSTATENM'], [0, 'CLGENDDT'], [0, 'ROPNYMD'], [0, 'SITEAREA'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEDT'], [0, 'UPTAENM'], [0, 'X'], [0, 'Y'], [0, 'SNTUPTAENM'], [0, 'MANEIPCNT'], [0, 'WMEIPCNT'], [0, 'TRDPJUBNSENM'], [0, 'WTRSPLYFACILSENM'], [0, 'TOTEPNUM'], [0, 'FCTYSILJOBEPCNT'], [0, 'FCTYPDTJOBEPCNT'], [0, 'BDNGOWNSENM'], [0, 'ISREAM'], [0, 'MULTUSNUPSOYN'], [0, 'FACILTOTSCP'], [0, 'JTUPSOASGNNO'], [0, 'JTUPSOMAINEDF'], [0, 'HOMEPAGE']], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'number', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_1545', 'table_names_original': ['GD_TN_BBS9'], 'column_names_original': [[-1, '*'], [0, 'NAME'], [0, 'ADDR'], [0, 'PHONE'], [0, 'ETC'], [0, 'LANGUAGE']], 'column_types': ['text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_4669', 'table_names_original': ['L_O_C_A_L_D_A_T_A_072213_G_J'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'TRDSTATEGBN'], [0, 'TRDSTATENM'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'CLGSTDT'], [0, 'ROPNYMD'], [0, 'SITETEL'], [0, 'SITEAREA'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPTAENM'], [0, 'X'], [0, 'Y'], [0, 'WMEIPCNT'], [0, 'TRDPJUBNSENM'], [0, 'LVSENM'], [0, 'WTRSPLYFACILSENM'], [0, 'TOTEPNUM'], [0, 'HOFFEPCNT'], [0, 'FCTYOWKEPCNT'], [0, 'FCTYSILJOBEPCNT'], [0, 'BDNGOWNSENM'], [0, 'ISREAM'], [0, 'MONAM'], [0, 'FACILTOTSCP'], [0, 'JTUPSOMAINEDF'], [0, 'HOMEPAGE']], 'column_types': ['text', 'number', 'text', 'time', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_70', 'table_names_original': ['L_O_C_A_L_D_A_T_A_020301'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'APVCANCELYMD'], [0, 'TRDSTATEGBN'], [0, 'TRDSTATENM'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'CLGSTDT'], [0, 'CLGENDDT'], [0, 'SITETEL'], [0, 'SITEAREA'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEDT'], [0, 'UPTAENM'], [0, 'Y'], [0, 'LINDJOBGBNNM'], [0, 'LINDPRCBGBNNM'], [0, 'LINDSEQNO'], [0, 'RGTMBDSNO'], [0, 'TOTEPNUM']], 'column_types': ['text', 'number', 'number', 'time', 'text', 'number', 'text', 'number', 'text', 'time', 'time', 'time', 'text', 'number', 'text', 'text', 'text', 'number', 'text', 'number', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'number']}
# {'db_id': 'seouldata_healthcare_405', 'table_names_original': ['L_O_C_A_L_D_A_T_A_010201'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNUMBER'], [0, 'APVPERMYMD'], [0, 'APVCANCELYMD'], [0, 'TRDSTATEGBN'], [0, 'TRDSTATENM'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'CLGSTDT'], [0, 'CLGENDDT'], [0, 'SITETEL'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEGBN'], [0, 'UPDATEDT'], [0, 'UPTAENM'], [0, 'Y'], [0, 'SAMPLENSNUM'], [0, 'PUPILDISTMEASNUM'], [0, 'DEFPTRFRTGGNUM'], [0, 'GLSWASHERNUM']], 'column_types': ['text', 'number', 'text', 'time', 'time', 'number', 'text', 'number', 'text', 'time', 'time', 'time', 'text', 'text', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_2403', 'table_names_original': ['GN_FOOD_COLLECT_CHECK_HYGIENE_BIZ'], 'column_names_original': [[-1, '*'], [0, 'CGG_CODE'], [0, 'SNT_COB_CODE'], [0, 'SNT_COB_NM'], [0, 'PLN_SE_CODE'], [0, 'PLN_SE_NM'], [0, 'CHK_PLN_NM'], [0, 'COL_PLN_NM'], [0, 'COL_PRFDOC_NO'], [0, 'COL_WHY_CODE'], [0, 'UPSO_NM'], [0, 'ATCL_GUN_CODE'], [0, 'ATCL_GUN_NM'], [0, 'ATCL_NM'], [0, 'PRDT_NM'], [0, 'RM_NM'], [0, 'PDT_UPSO_NM'], [0, 'COL_YMD'], [0, 'COL_QUA'], [0, 'PRDT_SIZE'], [0, 'COL_QY_IPT'], [0, 'PRD_YMD'], [0, 'PRDT_YUTONG_DLN'], [0, 'YUTONG_DLN_PRD_YMD_FROM'], [0, 'BCE_CODE'], [0, 'FACTORY_NM'], [0, 'NATIV_FRGNR_SE'], [0, 'NTN'], [0, 'ISP_SE'], [0, 'ISP_RT_REPLY_YMD'], [0, 'COL_ISP_RT_GBN'], [0, 'DEAL_SE'], [0, 'COL_ISP_SE'], [0, 'CTL_REGN_SE'], [0, 'COL_PLC_SE'], [0, 'DEAL_RT'], [0, 'COL_PDT_DEAL'], [0, 'GNT_NO'], [0, 'DRT_INSP_YMD']], 'column_types': ['text', 'number', 'number', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'time', 'number', 'text', 'text', 'time', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'time']}
# {'db_id': 'seouldata_healthcare_2212', 'table_names_original': ['L_O_C_A_L_D_A_T_A_072203_G_A'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'TRDSTATENM'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'ROPNYMD'], [0, 'SITETEL'], [0, 'SITEAREA'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEGBN'], [0, 'UPTAENM'], [0, 'X'], [0, 'Y'], [0, 'SNTUPTAENM'], [0, 'MANEIPCNT'], [0, 'WMEIPCNT'], [0, 'TRDPJUBNSENM'], [0, 'WTRSPLYFACILSENM'], [0, 'TOTEPNUM'], [0, 'HOFFEPCNT'], [0, 'FCTYOWKEPCNT'], [0, 'FCTYSILJOBEPCNT'], [0, 'FCTYPDTJOBEPCNT'], [0, 'BDNGOWNSENM'], [0, 'ISREAM'], [0, 'MONAM'], [0, 'FACILTOTSCP'], [0, 'JTUPSOASGNNO'], [0, 'JTUPSOMAINEDF']], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'number', 'text', 'text', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_3094', 'table_names_original': ['L_O_C_A_L_D_A_T_A_072302_Y_S'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'TRDSTATEGBN'], [0, 'TRDSTATENM'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'CLGSTDT'], [0, 'CLGENDDT'], [0, 'ROPNYMD'], [0, 'SITETEL'], [0, 'SITEAREA'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEGBN'], [0, 'UPDATEDT'], [0, 'UPTAENM'], [0, 'X'], [0, 'Y'], [0, 'SNTUPTAENM'], [0, 'MANEIPCNT'], [0, 'WMEIPCNT'], [0, 'LVSENM'], [0, 'WTRSPLYFACILSENM'], [0, 'TOTEPNUM'], [0, 'HOFFEPCNT'], [0, 'FCTYOWKEPCNT'], [0, 'FCTYSILJOBEPCNT'], [0, 'BDNGOWNSENM'], [0, 'ISREAM'], [0, 'MONAM'], [0, 'FACILTOTSCP'], [0, 'JTUPSOASGNNO'], [0, 'JTUPSOMAINEDF'], [0, 'HOMEPAGE']], 'column_types': ['text', 'number', 'text', 'time', 'number', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_3864', 'table_names_original': ['L_O_C_A_L_D_A_T_A_072202_D_D'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'APVCANCELYMD'], [0, 'TRDSTATEGBN'], [0, 'TRDSTATENM'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'CLGENDDT'], [0, 'SITETEL'], [0, 'SITEAREA'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'UPDATEGBN'], [0, 'UPDATEDT'], [0, 'UPTAENM'], [0, 'X'], [0, 'Y'], [0, 'MANEIPCNT'], [0, 'WMEIPCNT'], [0, 'WTRSPLYFACILSENM'], [0, 'TOTEPNUM'], [0, 'HOFFEPCNT'], [0, 'FCTYOWKEPCNT'], [0, 'FCTYPDTJOBEPCNT'], [0, 'BDNGOWNSENM'], [0, 'ISREAM'], [0, 'MONAM'], [0, 'FACILTOTSCP'], [0, 'JTUPSOASGNNO'], [0, 'JTUPSOMAINEDF'], [0, 'HOMEPAGE']], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_5400', 'table_names_original': ['TB_RPRT_CLIC_HOSP'], 'column_names_original': [[-1, '*'], [0, 'YKIHO'], [0, 'SEQNO'], [0, 'SGGUNM'], [0, 'YADMNM'], [0, 'RECUCLCD'], [0, 'CLICADDR'], [0, 'TELNO'], [0, 'CV19SPCMGATEXECYN'], [0, 'ADTSTADD'], [0, 'SUNMGTHRTXT'], [0, 'MONMGTHRTXT'], [0, 'TUEMGTHRTXT'], [0, 'WEDMGTHRTXT'], [0, 'THUMGTHRTXT'], [0, 'FRIMGTHRTXT'], [0, 'SATMGTHRTXT'], [0, 'XPOS'], [0, 'XPOSWGS84'], [0, 'YPOS'], [0, 'YPOSWGS84']], 'column_types': ['text', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'text', 'time', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number']}
# {'db_id': 'seouldata_healthcare_683', 'table_names_original': ['L_O_C_A_L_D_A_T_A_010202'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'TRDSTATENM'], [0, 'DTLSTATEGBN'], [0, 'DCBYMD'], [0, 'CLGSTDT'], [0, 'CLGENDDT'], [0, 'ROPNYMD'], [0, 'SITETEL'], [0, 'SITEAREA'], [0, 'SITEPOSTNO'], [0, 'RDNWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEGBN'], [0, 'UPDATEDT'], [0, 'X'], [0, 'Y'], [0, 'MEDKIND'], [0, 'SJYN']], 'column_types': ['text', 'number', 'text', 'time', 'text', 'text', 'time', 'time', 'time', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_1761', 'table_names_original': ['L_O_C_A_L_D_A_T_A_072203_D_D'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'APVCANCELYMD'], [0, 'TRDSTATEGBN'], [0, 'TRDSTATENM'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'CLGSTDT'], [0, 'CLGENDDT'], [0, 'ROPNYMD'], [0, 'SITETEL'], [0, 'SITEAREA'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEGBN'], [0, 'UPDATEDT'], [0, 'UPTAENM'], [0, 'X'], [0, 'Y'], [0, 'SNTUPTAENM'], [0, 'MANEIPCNT'], [0, 'WMEIPCNT'], [0, 'TRDPJUBNSENM'], [0, 'LVSENM'], [0, 'WTRSPLYFACILSENM'], [0, 'FCTYOWKEPCNT'], [0, 'FCTYSILJOBEPCNT'], [0, 'FCTYPDTJOBEPCNT'], [0, 'BDNGOWNSENM'], [0, 'ISREAM'], [0, 'MONAM'], [0, 'FACILTOTSCP'], [0, 'JTUPSOMAINEDF'], [0, 'HOMEPAGE']], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'text', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_1515', 'table_names_original': ['GANGSEO_ADMIN_MESURE'], 'column_names_original': [[-1, '*'], [0, 'CGG_CODE'], [0, 'ADM_DISPO_YMD'], [0, 'GNT_NO'], [0, 'SNT_COB_NM'], [0, 'SNT_UPTAE_NM'], [0, 'UPSO_NM'], [0, 'SITE_ADDR_RD'], [0, 'SITE_ADDR'], [0, 'DRT_INSP_YMD'], [0, 'ADMM_STATE'], [0, 'DISPO_CTN'], [0, 'BAS_LAW'], [0, 'VIOL_CN'], [0, 'DISPO_CTN_DT'], [0, 'NT_GBN_CODE'], [0, 'JB_ORG'], [0, 'TAKE_YMD'], [0, 'TRDP_AREA']], 'column_types': ['text', 'number', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'time', 'number']}
# {'db_id': 'seouldata_healthcare_2602', 'table_names_original': ['SP_ADMIN_MESURE_FOOD'], 'column_names_original': [[-1, '*'], [0, 'CGG_CODE'], [0, 'ADM_DISPO_YMD'], [0, 'GNT_NO'], [0, 'SNT_COB_NM'], [0, 'SNT_UPTAE_NM'], [0, 'UPSO_NM'], [0, 'SITE_ADDR'], [0, 'DRT_INSP_YMD'], [0, 'ADMM_STATE'], [0, 'DISPO_CTN'], [0, 'VIOR_SORT'], [0, 'BAS_LAW'], [0, 'VIOR_YMD'], [0, 'VIOL_CN'], [0, 'DISPO_CTN_DT'], [0, 'DISPO_GIGAN'], [0, 'NT_GBN_CODE'], [0, 'TRDP_AREA'], [0, 'MNG_GBN_NM']], 'column_types': ['text', 'number', 'number', 'number', 'text', 'text', 'text', 'text', 'time', 'text', 'text', 'text', 'text', 'time', 'text', 'text', 'text', 'text', 'number', 'text']}
# {'db_id': 'seouldata_healthcare_2313', 'table_names_original': ['L_O_C_A_L_D_A_T_A_010203_S_C'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'TRDSTATEGBN'], [0, 'TRDSTATENM'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'CLGSTDT'], [0, 'ROPNYMD'], [0, 'SITETEL'], [0, 'SITEAREA'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEDT'], [0, 'X'], [0, 'Y'], [0, 'MEDKIND'], [0, 'TOTSCP'], [0, 'TRDSCP']], 'column_types': ['text', 'number', 'text', 'time', 'number', 'text', 'number', 'text', 'time', 'time', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'number', 'time', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_3867', 'table_names_original': ['L_O_C_A_L_D_A_T_A_072302_D_J'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'APVCANCELYMD'], [0, 'TRDSTATEGBN'], [0, 'TRDSTATENM'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'CLGSTDT'], [0, 'CLGENDDT'], [0, 'ROPNYMD'], [0, 'SITEAREA'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEGBN'], [0, 'UPDATEDT'], [0, 'UPTAENM'], [0, 'X'], [0, 'Y'], [0, 'SNTUPTAENM'], [0, 'MANEIPCNT'], [0, 'WMEIPCNT'], [0, 'TRDPJUBNSENM'], [0, 'WTRSPLYFACILSENM'], [0, 'FCTYOWKEPCNT'], [0, 'FCTYPDTJOBEPCNT'], [0, 'BDNGOWNSENM'], [0, 'ISREAM'], [0, 'MONAM'], [0, 'FACILTOTSCP'], [0, 'JTUPSOASGNNO'], [0, 'JTUPSOMAINEDF'], [0, 'HOMEPAGE']], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'text', 'text', 'time', 'text', 'text', 'text', 'number', 'number', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_5338', 'table_names_original': ['GB_GLSS_BSSH_STTUS_INFO'], 'column_names_original': [[-1, '*'], [0, 'GLSS_BBSH_STTUS'], [0, 'BPLC_LOCPLC'], [0, 'BPCL_TELNO']], 'column_types': ['text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_3358', 'table_names_original': ['L_O_C_A_L_D_A_T_A_072301_Y_D'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'APVCANCELYMD'], [0, 'TRDSTATEGBN'], [0, 'TRDSTATENM'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'CLGENDDT'], [0, 'ROPNYMD'], [0, 'SITETEL'], [0, 'SITEAREA'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEDT'], [0, 'X'], [0, 'Y'], [0, 'SNTUPTAENM'], [0, 'MANEIPCNT'], [0, 'TRDPJUBNSENM'], [0, 'LVSENM'], [0, 'WTRSPLYFACILSENM'], [0, 'TOTEPNUM'], [0, 'HOFFEPCNT'], [0, 'FCTYOWKEPCNT'], [0, 'FCTYPDTJOBEPCNT'], [0, 'BDNGOWNSENM'], [0, 'FACILTOTSCP']], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'text', 'text', 'time', 'text', 'text', 'text', 'number', 'number', 'text', 'text', 'number', 'text', 'number', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_2191', 'table_names_original': ['L_O_C_A_L_D_A_T_A_072203_D_J'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'TRDSTATEGBN'], [0, 'TRDSTATENM'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'CLGSTDT'], [0, 'CLGENDDT'], [0, 'ROPNYMD'], [0, 'SITETEL'], [0, 'SITEAREA'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEGBN'], [0, 'UPDATEDT'], [0, 'UPTAENM'], [0, 'X'], [0, 'Y'], [0, 'SNTUPTAENM'], [0, 'MANEIPCNT'], [0, 'WMEIPCNT'], [0, 'TRDPJUBNSENM'], [0, 'LVSENM'], [0, 'HOFFEPCNT'], [0, 'FCTYPDTJOBEPCNT'], [0, 'BDNGOWNSENM'], [0, 'MONAM'], [0, 'FACILTOTSCP'], [0, 'JTUPSOASGNNO'], [0, 'HOMEPAGE']], 'column_types': ['text', 'number', 'text', 'time', 'number', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_1962', 'table_names_original': ['L_O_C_A_L_D_A_T_A_072211_J_N'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'APVCANCELYMD'], [0, 'TRDSTATENM'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'CLGSTDT'], [0, 'SITETEL'], [0, 'SITEAREA'], [0, 'SITEWHLADDR'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'X'], [0, 'Y'], [0, 'SNTUPTAENM'], [0, 'MANEIPCNT'], [0, 'WMEIPCNT'], [0, 'LVSENM'], [0, 'HOFFEPCNT'], [0, 'FCTYSILJOBEPCNT'], [0, 'ISREAM'], [0, 'MULTUSNUPSOYN'], [0, 'JTUPSOASGNNO'], [0, 'HOMEPAGE']], 'column_types': ['text', 'number', 'text', 'time', 'text', 'text', 'number', 'text', 'time', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_3651', 'table_names_original': ['L_O_C_A_L_D_A_T_A_093011_Y_S'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'APVCANCELYMD'], [0, 'TRDSTATEGBN'], [0, 'TRDSTATENM'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'CLGSTDT'], [0, 'CLGENDDT'], [0, 'SITETEL'], [0, 'SITEAREA'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEGBN'], [0, 'UPDATEDT'], [0, 'X'], [0, 'Y'], [0, 'OFEAR'], [0, 'DISFETVEHGARAR'], [0, 'HNDUSESTLZNUM'], [0, 'DYNPWSPRAYNUM'], [0, 'HDOPTDSPRAYNUM'], [0, 'PROTGLSNUM'], [0, 'PROTUSECLOTNUM'], [0, 'VACUCLERNUM']], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_3260', 'table_names_original': ['L_O_C_A_L_D_A_T_A_072218_G_D'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'APVCANCELYMD'], [0, 'TRDSTATENM'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'CLGSTDT'], [0, 'ROPNYMD'], [0, 'SITETEL'], [0, 'SITEAREA'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEGBN'], [0, 'X'], [0, 'Y'], [0, 'MANEIPCNT'], [0, 'WMEIPCNT'], [0, 'TRDPJUBNSENM'], [0, 'LVSENM'], [0, 'WTRSPLYFACILSENM'], [0, 'FCTYOWKEPCNT'], [0, 'FCTYSILJOBEPCNT'], [0, 'FCTYPDTJOBEPCNT'], [0, 'ISREAM'], [0, 'MONAM'], [0, 'FACILTOTSCP'], [0, 'JTUPSOMAINEDF'], [0, 'HOMEPAGE']], 'column_types': ['text', 'number', 'text', 'time', 'text', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_3315', 'table_names_original': ['L_O_C_A_L_D_A_T_A_072202_S_C'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'TRDSTATEGBN'], [0, 'TRDSTATENM'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'CLGSTDT'], [0, 'CLGENDDT'], [0, 'ROPNYMD'], [0, 'SITETEL'], [0, 'SITEAREA'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'UPDATEGBN'], [0, 'UPTAENM'], [0, 'X'], [0, 'Y'], [0, 'MANEIPCNT'], [0, 'WMEIPCNT'], [0, 'LVSENM'], [0, 'WTRSPLYFACILSENM'], [0, 'TOTEPNUM'], [0, 'FCTYOWKEPCNT'], [0, 'FCTYSILJOBEPCNT'], [0, 'FCTYPDTJOBEPCNT'], [0, 'ISREAM'], [0, 'MONAM'], [0, 'JTUPSOASGNNO'], [0, 'JTUPSOMAINEDF'], [0, 'HOMEPAGE']], 'column_types': ['text', 'number', 'text', 'time', 'number', 'text', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_1816', 'table_names_original': ['L_O_C_A_L_D_A_T_A_010106_J_G'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVCANCELYMD'], [0, 'TRDSTATENM'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'SITETEL'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEGBN'], [0, 'UPDATEDT'], [0, 'UPTAENM'], [0, 'Y'], [0, 'PHARMTRDAR'], [0, 'ASGNYMD']], 'column_types': ['text', 'number', 'text', 'text', 'text', 'number', 'text', 'time', 'text', 'number', 'text', 'text', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'time']}
# {'db_id': 'seouldata_healthcare_1740', 'table_names_original': ['L_O_C_A_L_D_A_T_A_072211_G_R'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'TRDSTATEGBN'], [0, 'TRDSTATENM'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'CLGENDDT'], [0, 'ROPNYMD'], [0, 'SITEAREA'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEDT'], [0, 'UPTAENM'], [0, 'X'], [0, 'Y'], [0, 'SNTUPTAENM'], [0, 'MANEIPCNT'], [0, 'WMEIPCNT'], [0, 'TRDPJUBNSENM'], [0, 'LVSENM'], [0, 'WTRSPLYFACILSENM'], [0, 'HOFFEPCNT'], [0, 'FCTYSILJOBEPCNT'], [0, 'FCTYPDTJOBEPCNT'], [0, 'BDNGOWNSENM'], [0, 'FACILTOTSCP'], [0, 'HOMEPAGE']], 'column_types': ['text', 'number', 'text', 'time', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'number', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_2102', 'table_names_original': ['L_O_C_A_L_D_A_T_A_010106_G_J'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'APVCANCELYMD'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'ROPNYMD'], [0, 'SITETEL'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'UPDATEGBN'], [0, 'UPDATEDT'], [0, 'X'], [0, 'Y'], [0, 'PHARMTRDAR'], [0, 'ASGNYMD']], 'column_types': ['text', 'number', 'text', 'time', 'time', 'number', 'text', 'text', 'text', 'number', 'text', 'number', 'text', 'text', 'time', 'text', 'text', 'text', 'time']}
# {'db_id': 'seouldata_healthcare_2413', 'table_names_original': ['GN_FOOD_COLLECT_CHECK'], 'column_names_original': [[-1, '*'], [0, 'CGG_CODE'], [0, 'SNT_COB_CODE'], [0, 'SNT_COB_NM'], [0, 'PLN_SE_CODE'], [0, 'PLN_SE_NM'], [0, 'CHK_PLN_NM'], [0, 'COL_PLN_NM'], [0, 'COL_WHY_CODE'], [0, 'UPSO_NM'], [0, 'ATCL_GUN_CODE'], [0, 'ATCL_GUN_NM'], [0, 'ATCL_NM'], [0, 'EDF_NM'], [0, 'RM_NM'], [0, 'PDT_UPSO_NM'], [0, 'COL_YMD'], [0, 'COL_QY_IPT'], [0, 'PRD_YMD'], [0, 'LOT_NO'], [0, 'PRDT_YUTONG_DLN'], [0, 'DEPO_STATE_CODE'], [0, 'BCE_CODE'], [0, 'FACTORY_NM'], [0, 'NATIV_FRGNR_SE'], [0, 'ISP_SE'], [0, 'ISP_REQ_YMD'], [0, 'ISP_RT_REPLY_YMD'], [0, 'DEAL_SE'], [0, 'COL_ISP_SE'], [0, 'CTL_REGN_SE'], [0, 'COL_PLC_SE'], [0, 'DEAL_RT'], [0, 'SITE_ADDR'], [0, 'DRT_INSP_YMD']], 'column_types': ['text', 'number', 'number', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'time', 'text', 'time', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'time', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'time']}
# {'db_id': 'seouldata_healthcare_2646', 'table_names_original': ['SEODAEMUN_ADMIN_MESURE_PUBLIC'], 'column_names_original': [[-1, '*'], [0, 'CGG_CODE'], [0, 'ADM_DISPO_YMD'], [0, 'GNT_NO'], [0, 'SNT_COB_NM'], [0, 'SNT_UPTAE_NM'], [0, 'UPSO_NM'], [0, 'SITE_ADDR_RD'], [0, 'ADMM_STATE'], [0, 'DISPO_CTN'], [0, 'VIOR_SORT'], [0, 'VIOR_YMD'], [0, 'VIOL_CN'], [0, 'DISPO_CTN_DT'], [0, 'DISPO_GIGAN'], [0, 'INSP_GBN_CODE'], [0, 'NT_GBN_CODE'], [0, 'JB_ORG'], [0, 'TAKE_YMD'], [0, 'TRDP_AREA']], 'column_types': ['text', 'number', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'time', 'number']}
# {'db_id': 'seouldata_healthcare_2665', 'table_names_original': ['GD_FOOD_HYGIENE_BIZ_LOC_MANAGE'], 'column_names_original': [[-1, '*'], [0, 'GD_FOOD_HYGIENE_CGG_CODE'], [0, 'GD_FOOD_HYGIENE_CGG_NM'], [0, 'REGN_NM'], [0, 'GD_FOOD_HYGIENE_SNT_UPTAE_NM'], [0, 'CNT']], 'column_types': ['text', 'number', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_2686', 'table_names_original': ['DONGDEAMOON_MODEL_RESTAURANT_CANCEL'], 'column_names_original': [[-1, '*'], [0, 'CGG_CODE'], [0, 'ASGN_YY'], [0, 'ASGN_SNO'], [0, 'APPL_YMD'], [0, 'ASGN_YMD'], [0, 'ASGN_CANCEL_YMD'], [0, 'UPSO_NM'], [0, 'SITE_ADDR'], [0, 'PERM_NT_NO'], [0, 'SNT_UPTAE_NM'], [0, 'ASGN_CANCEL_WHY'], [0, 'MAIN_EDF'], [0, 'TRDP_AREA'], [0, 'ADMDNG_NM'], [0, 'GRADE_FACIL_GBN']], 'column_types': ['text', 'number', 'time', 'text', 'time', 'time', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_3887', 'table_names_original': ['L_O_C_A_L_D_A_T_A_072209_G_S'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'APVCANCELYMD'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'CLGSTDT'], [0, 'CLGENDDT'], [0, 'ROPNYMD'], [0, 'SITETEL'], [0, 'SITEAREA'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEGBN'], [0, 'UPDATEDT'], [0, 'UPTAENM'], [0, 'X'], [0, 'Y'], [0, 'SNTUPTAENM'], [0, 'MANEIPCNT'], [0, 'TRDPJUBNSENM'], [0, 'LVSENM'], [0, 'WTRSPLYFACILSENM'], [0, 'FCTYOWKEPCNT'], [0, 'FCTYSILJOBEPCNT'], [0, 'FCTYPDTJOBEPCNT'], [0, 'BDNGOWNSENM'], [0, 'FACILTOTSCP'], [0, 'JTUPSOASGNNO'], [0, 'JTUPSOMAINEDF'], [0, 'HOMEPAGE']], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'number', 'number', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_2942', 'table_names_original': ['L_O_C_A_L_D_A_T_A_072210_D_J'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'TRDSTATEGBN'], [0, 'TRDSTATENM'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'CLGSTDT'], [0, 'ROPNYMD'], [0, 'SITETEL'], [0, 'SITEAREA'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEDT'], [0, 'UPTAENM'], [0, 'Y'], [0, 'SNTUPTAENM'], [0, 'MANEIPCNT'], [0, 'WMEIPCNT'], [0, 'TRDPJUBNSENM'], [0, 'LVSENM'], [0, 'WTRSPLYFACILSENM'], [0, 'TOTEPNUM'], [0, 'HOFFEPCNT'], [0, 'FCTYPDTJOBEPCNT'], [0, 'BDNGOWNSENM'], [0, 'MONAM'], [0, 'FACILTOTSCP']], 'column_types': ['text', 'number', 'text', 'time', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'number', 'number', 'text', 'text', 'number', 'text', 'number', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_4038', 'table_names_original': ['L_O_C_A_L_D_A_T_A_051801_G_S'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'APVCANCELYMD'], [0, 'TRDSTATENM'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'CLGSTDT'], [0, 'CLGENDDT'], [0, 'ROPNYMD'], [0, 'SITETEL'], [0, 'SITEAREA'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'UPDATEGBN'], [0, 'UPDATEDT'], [0, 'UPTAENM'], [0, 'X'], [0, 'Y'], [0, 'SNTUPTAENM'], [0, 'BDNGJISGFLRCNT'], [0, 'BDNGUNDERFLRCNT'], [0, 'USEJISGSTFLR'], [0, 'YANGSILCNT'], [0, 'CHAIRCNT'], [0, 'CNDPERMNTWHY'], [0, 'RCVDRYNCNT'], [0, 'ABEDCNT'], [0, 'MULTUSNUPSOYN']], 'column_types': ['text', 'number', 'text', 'time', 'text', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_2394', 'table_names_original': ['JUNGGU_FOOD_COLLECT_CHECK'], 'column_names_original': [[-1, '*'], [0, 'CGG_CODE'], [0, 'SNT_COB_CODE'], [0, 'SNT_COB_NM'], [0, 'PLN_SE_CODE'], [0, 'PLN_SE_NM'], [0, 'COL_PRFDOC_NO'], [0, 'UPSO_NM'], [0, 'ATCL_GUN_CODE'], [0, 'ATCL_GUN_NM'], [0, 'ATCL_NM'], [0, 'PRDT_NM'], [0, 'PDT_UPSO_NM'], [0, 'COL_YMD'], [0, 'COL_QUA'], [0, 'PRDT_SIZE'], [0, 'COL_UNIT'], [0, 'PRD_YMD'], [0, 'PRDT_YUTONG_DLN'], [0, 'DEPO_STATE_CODE'], [0, 'BCE_CODE'], [0, 'CHD_SMBL_FD_KD_CODE'], [0, 'ISP_REQ_ORG_NM'], [0, 'FACTORY_NM'], [0, 'NATIV_FRGNR_SE'], [0, 'NTN'], [0, 'ISP_REQ_YMD'], [0, 'COL_ISP_RT_GBN'], [0, 'COL_ISP_SE'], [0, 'CTL_REGN_SE'], [0, 'COL_PDT_DEAL'], [0, 'GNT_NO'], [0, 'DRT_INSP_YMD']], 'column_types': ['text', 'number', 'number', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'time', 'number', 'text', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'time', 'text', 'text', 'text', 'text', 'number', 'time']}
# {'db_id': 'seouldata_healthcare_2438', 'table_names_original': ['GEUMCHEON_PUBLIC_HYGIENE_BIZ_LOC_MANAGE'], 'column_names_original': [[-1, '*'], [0, 'GC_FOOD_HYGIENE_CGG_CODE'], [0, 'GC_FOOD_HYGIENE_CGG_NM'], [0, 'REGN_NM'], [0, 'SNT_COB_NM'], [0, 'CNT']], 'column_types': ['text', 'number', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_2606', 'table_names_original': ['SEODAEMUN_ADMIN_MESURE_FOOD'], 'column_names_original': [[-1, '*'], [0, 'CGG_CODE'], [0, 'ADM_DISPO_YMD'], [0, 'GNT_NO'], [0, 'SNT_COB_NM'], [0, 'SNT_UPTAE_NM'], [0, 'UPSO_NM'], [0, 'SITE_ADDR_RD'], [0, 'SITE_ADDR'], [0, 'DRT_INSP_YMD'], [0, 'DISPO_CTN'], [0, 'BAS_LAW'], [0, 'VIOR_YMD'], [0, 'VIOL_CN'], [0, 'INSP_GBN_CODE'], [0, 'NT_GBN_CODE'], [0, 'TAKE_YMD'], [0, 'MNG_GBN_NM']], 'column_types': ['text', 'number', 'time', 'number', 'text', 'text', 'text', 'text', 'text', 'time', 'text', 'text', 'time', 'text', 'text', 'text', 'time', 'text']}
# {'db_id': 'seouldata_healthcare_2692', 'table_names_original': ['GWANGJIN_FOOD_HYGIENE_BIZ_LOC_MANAGE'], 'column_names_original': [[-1, '*'], [0, 'GJ_FOOD_HYGIENE_CGG_CODE'], [0, 'GJ_FOOD_HYGIENE_CGG_NM'], [0, 'REGN_NM'], [0, 'SNT_UPTAE_NM'], [0, 'CNT']], 'column_types': ['text', 'number', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_2739', 'table_names_original': ['JUNGNANG_MODEL_RESTAURANT_DESIGNATE'], 'column_names_original': [[-1, '*'], [0, 'JN_RESTAURANT_CGG_CODE'], [0, 'JN_RESTAURANT_ASGN_YY'], [0, 'JN_RESTAURANT_ASGN_SNO'], [0, 'JN_RESTAURANT_APPL_YMD'], [0, 'JN_RESTAURANT_ASGN_YMD'], [0, 'UPSO_NM'], [0, 'SNT_UPTAE_NM'], [0, 'MAIN_EDF'], [0, 'JN_RESTAURANT_TRDP_AREA'], [0, 'ADMDNG_NM'], [0, 'JN_RESTAURANT_UPSO_SITE_TELNO']], 'column_types': ['text', 'number', 'time', 'text', 'time', 'time', 'text', 'text', 'text', 'number', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_4000', 'table_names_original': ['L_O_C_A_L_D_A_T_A_072201_N_W'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'APVCANCELYMD'], [0, 'TRDSTATEGBN'], [0, 'TRDSTATENM'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'SITETEL'], [0, 'SITEAREA'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEGBN'], [0, 'UPDATEDT'], [0, 'UPTAENAME'], [0, 'Y'], [0, 'SNTUPTAENM'], [0, 'MANEIPCNT'], [0, 'TRDPJUBNSENM'], [0, 'WTRSPLYFACILSENM'], [0, 'TOTEPNUM'], [0, 'HOFFEPCNT'], [0, 'FCTYOWKEPCNT'], [0, 'FCTYSILJOBEPCNT'], [0, 'FCTYPDTJOBEPCNT'], [0, 'BDNGOWNSENM'], [0, 'ISREAM'], [0, 'MONAM'], [0, 'MULTUSNUPSOYN'], [0, 'FACILTOTSCP'], [0, 'JTUPSOASGNNO'], [0, 'JTUPSOMAINEDF'], [0, 'HOMEPAGE']], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'number', 'number', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_3510', 'table_names_original': ['L_O_C_A_L_D_A_T_A_062001_S_C'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'CLGENDDT'], [0, 'ROPNYMD'], [0, 'SITETEL'], [0, 'SITEAREA'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEGBN'], [0, 'UPDATEDT'], [0, 'UPTAENM'], [0, 'X'], [0, 'Y'], [0, 'SNTUPTAENM'], [0, 'BDNGJISGFLRCNT'], [0, 'BDNGUNDERFLRCNT'], [0, 'USEJISGSTFLR'], [0, 'HANSHILCNT'], [0, 'YANGSILCNT'], [0, 'YOKSILCNT'], [0, 'CHAIRCNT'], [0, 'BDNGOWNSENM'], [0, 'WASHMCCNT'], [0, 'WMEIPCNT'], [0, 'ABEDCNT'], [0, 'MULTUSNUPSOYN']], 'column_types': ['text', 'number', 'text', 'time', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_2146', 'table_names_original': ['L_O_C_A_L_D_A_T_A_072203_J_N'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'APVCANCELYMD'], [0, 'TRDSTATEGBN'], [0, 'TRDSTATENM'], [0, 'DTLSTATEGBN'], [0, 'DCBYMD'], [0, 'CLGENDDT'], [0, 'ROPNYMD'], [0, 'SITETEL'], [0, 'SITEAREA'], [0, 'SITEPOSTNO'], [0, 'SITEWHLADDR'], [0, 'RDNWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEGBN'], [0, 'UPDATEDT'], [0, 'UPTAENM'], [0, 'X'], [0, 'Y'], [0, 'SNTUPTAENM'], [0, 'WMEIPCNT'], [0, 'WTRSPLYFACILSENM'], [0, 'TOTEPNUM'], [0, 'HOFFEPCNT'], [0, 'FCTYOWKEPCNT'], [0, 'FCTYSILJOBEPCNT'], [0, 'FCTYPDTJOBEPCNT'], [0, 'BDNGOWNSENM'], [0, 'ISREAM'], [0, 'MONAM'], [0, 'MULTUSNUPSOYN'], [0, 'FACILTOTSCP'], [0, 'JTUPSOMAINEDF']], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'text', 'number', 'time', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'seouldata_healthcare_1951', 'table_names_original': ['L_O_C_A_L_D_A_T_A_010105_G_R'], 'column_names_original': [[-1, '*'], [0, 'OPNSFTEAMCODE'], [0, 'MGTNO'], [0, 'APVPERMYMD'], [0, 'APVCANCELYMD'], [0, 'DTLSTATEGBN'], [0, 'DTLSTATENM'], [0, 'DCBYMD'], [0, 'CLGSTDT'], [0, 'SITETEL'], [0, 'SITEAREA'], [0, 'SITEWHLADDR'], [0, 'RDNPOSTNO'], [0, 'BPLCNM'], [0, 'LASTMODTS'], [0, 'UPDATEGBN'], [0, 'UPDATEDT'], [0, 'UPTAENM'], [0, 'X'], [0, 'Y'], [0, 'STORETRDAR']], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text']}
# ...
# {'db_id': 'seoulpopulation_publicadministration_30', 'table_names_original': ['POP_030'], 'column_names_original': [[-1, '*'], [0, 'STATS_YR'], [0, 'SIGUNGU_NM'], [0, 'SEX_NM'], [0, 'AGEGRD_NM'], [0, 'MVMN_TYPE_NM'], [0, 'POPL_CNT'], [0, 'ADMDONG_CD'], [0, 'AGEGRD_CD']], 'column_types': ['text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'number']}
# {'db_id': 'seoulpopulation_publicadministration_21', 'table_names_original': ['POP_021'], 'column_names_original': [[-1, '*'], [0, 'STATS_YR'], [0, 'SIGUNGU_NM'], [0, 'AGEGRD_NM'], [0, 'BIRTH_CNT'], [0, 'AGEGRD_CD'], [0, 'ADMDONG_CD']], 'column_types': ['text', 'text', 'text', 'text', 'number', 'number', 'text']}
# {'db_id': 'seoulpopulation_publicadministration_25', 'table_names_original': ['POP_025'], 'column_names_original': [[-1, '*'], [0, 'STATS_YR'], [0, 'SIGUNGU_NM'], [0, 'AGEGRD_NM'], [0, 'SEX_NM'], [0, 'DTH_CNT'], [0, 'DTH_RT'], [0, 'AGEGRD_CD'], [0, 'ADMDONG_CD']], 'column_types': ['text', 'number', 'text', 'text', 'text', 'number', 'number', 'number', 'number']}
# {'db_id': 'seoulpopulation_publicadministration_10', 'table_names_original': ['POP_010'], 'column_names_original': [[-1, '*'], [0, 'STATS_YR'], [0, 'SIGUNGU_NM'], [0, 'EPMNDN_NM'], [0, 'HSHLD_TYPE_NM'], [0, 'HSHLD_CNT'], [0, 'ADMDONG_CD'], [0, 'HSHLD_TYPE_CD']], 'column_types': ['text', 'text', 'text', 'text', 'text', 'number', 'text', 'text']}
# {'db_id': 'seoulpopulation_publicadministration_3', 'table_names_original': ['POP_003'], 'column_names_original': [[-1, '*'], [0, 'STATS_YR'], [0, 'SIGUNGU_NM'], [0, 'EPMNDN_NM'], [0, 'SEX_NM'], [0, 'AGEGRD_NM'], [0, 'POPL_CNT'], [0, 'ADMDONG_CD'], [0, 'AGEGRD_CD']], 'column_types': ['text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'number']}
# {'db_id': 'publicdata_transportation_1564', 'table_names_original': ['CURRENT_STS_PASSENGERS_BUS_STOP_GWANGJU'], 'column_names_original': [[-1, '*'], [0, 'RECTIFICATION'], [0, 'STOP_NUMBER_ARS_ID'], [0, 'KWON_JONG_SEON'], [0, 'RIDING'], [0, 'TRANSACTION_CNT']], 'column_types': ['text', 'text', 'number', 'text', 'text', 'number']}
# {'db_id': 'publicdata_transportation_618', 'table_names_original': ['STS_AGM_INSPECTION_IPAB_VESSELS'], 'column_names_original': [[-1, '*'], [0, 'INSPECTION_YEAR'], [0, 'TYPE_SHIP'], [0, 'SHIP_WEIGHT'], [0, 'INSPECTION_FEE_KRW_1_000'], [0, 'NUMBER_CASES_DEFAULT'], [0, 'NUMBER_CASES_SURCHARGE']], 'column_types': ['text', 'number', 'text', 'text', 'number', 'number', 'number']}
# {'db_id': 'publicdata_transportation_206', 'table_names_original': ['MAJOR_SPECIFICATIONS_KALIS_P_BRIDGE_FAC'], 'column_names_original': [[-1, '*'], [0, 'FACILITY_NAME'], [0, 'ADDRESS'], [0, 'BRIDGE_TYPE'], [0, 'BRIDGE_EXTENSION'], [0, 'LANE_NUMBER'], [0, 'SPAN_NUMBER'], [0, 'MAXIMUM_SPAN_COUNT']], 'column_types': ['text', 'text', 'text', 'text', 'number', 'number', 'number', 'number']}
# {'db_id': 'publicdata_transportation_858', 'table_names_original': ['NUM_PEOPLE_GETTING_OFF_BTC_TIME_ZONE'], 'column_names_original': [[-1, '*'], [0, 'REVERSE_NUMBER'], [0, 'STATION_NAME'], [0, 'YEAR_MONTH_DAY'], [0, 'DAY_OF_THE_WEEK'], [0, 'DIVISION'], [0, 'TOTAL'], [0, 'H_01_02'], [0, 'H_02_03'], [0, 'H_03_04'], [0, 'H_04_05'], [0, 'H_05_06'], [0, 'H_06_07'], [0, 'H_07_08'], [0, 'H_08_09'], [0, 'H_09_10'], [0, 'H_10_11'], [0, 'H_11_12'], [0, 'H_12_13'], [0, 'H_13_14'], [0, 'H_14_15'], [0, 'H_15_16'], [0, 'H_16_17'], [0, 'H_17_18'], [0, 'H_18_19'], [0, 'H_19_20'], [0, 'H_20_21'], [0, 'H_21_22'], [0, 'H_22_23'], [0, 'H_23_24'], [0, 'H_24_01']], 'column_types': ['text', 'number', 'text', 'time', 'text', 'text', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number']}
# {'db_id': 'publicdata_transportation_946', 'table_names_original': ['SELMETRO_MONTHLY_DROP_OFF_NUM'], 'column_names_original': [[-1, '*'], [0, 'ANNUAL'], [0, 'LINE'], [0, 'REVERSE_NUMBER'], [0, 'STATION_NAME'], [0, 'JANUARY_2022'], [0, 'FEBRUARY_2022'], [0, 'MARCH_2022'], [0, 'APRIL_2022'], [0, 'MAY_2022']], 'column_types': ['text', 'number', 'number', 'number', 'text', 'number', 'number', 'number', 'number', 'number']}
# {'db_id': 'publicdata_transportation_724', 'table_names_original': ['INCHEON_SEO_GU_BICYCLE_FAC'], 'column_names_original': [[-1, '*'], [0, 'CATEGORY'], [0, 'INSTALLATION_LOCATION'], [0, 'ADDRESS'], [0, 'TOTAL_NUMBER_OF_STORAGE'], [0, 'AIR_INJECTION'], [0, 'DATA_STANDARD_DATE']], 'column_types': ['text', 'text', 'text', 'text', 'number', 'text', 'time']}
# {'db_id': 'publicdata_transportation_2774', 'table_names_original': ['C_STS_GGAY_SPACE_INFO_SYS_SPEED_BARRIER'], 'column_names_original': [[-1, '*'], [0, 'MANAGEMENT_NUMY'], [0, 'STORM_SURGEZ'], [0, 'EXTA'], [0, 'JURISDICTIONB'], [0, 'INS_DTC']], 'column_types': ['text', 'number', 'number', 'number', 'text', 'time']}
# {'db_id': 'publicdata_transportation_3032', 'table_names_original': ['I_STS_GG_SU_BUS_ARRIVAL_INFO'], 'column_names_original': [[-1, '*'], [0, 'SERIAL_NUMB'], [0, 'NM_BUS_STOPC'], [0, 'BUS_STOP_NUMD'], [0, 'YEAR_INSE'], [0, 'EQUIPMENT_TYPEF'], [0, 'EQUIPMENT_TYPEG']], 'column_types': ['text', 'number', 'text', 'number', 'number', 'text', 'text']}
# {'db_id': 'publicdata_transportation_3631', 'table_names_original': ['GNJJ_BUS_INFO_GUIDE_I_STS'], 'column_names_original': [[-1, '*'], [0, 'NUMB'], [0, 'BUS_STOPC'], [0, 'NM_BUS_STOPD'], [0, 'DIRECTIONE'], [0, 'SORTATIONF'], [0, 'ADDRESSG'], [0, 'INS_YEARH'], [0, 'DATA_BASE_DTI']], 'column_types': ['text', 'number', 'number', 'text', 'text', 'text', 'text', 'text', 'time']}
# {'db_id': 'publicdata_transportation_3850', 'table_names_original': ['GGGJ_ADJACENT_AREA_TRAVEL_ROUTE'], 'column_names_original': [[-1, '*'], [0, 'GEOGRAPHICAL_FEATURE_CDI'], [0, 'DESTINATIONJ'], [0, 'TRANSIT_ROUTEK']], 'column_types': ['text', 'text', 'text', 'text']}
# {'db_id': 'publicdata_transportation_1940', 'table_names_original': ['KOTSA_AUTOMOBILE_MANUFACTURING_DEFECT_REPORT_INFO'], 'column_names_original': [[-1, '*'], [0, 'DATE_OF_RECEIPT'], [0, 'PRODUCER'], [0, 'NOMINATION'], [0, 'MODEL_YEAR']], 'column_types': ['text', 'time', 'text', 'text', 'number']}
# {'db_id': 'publicdata_transportation_4397', 'table_names_original': ['P_GETTING_OUT_KORAIL_METROPOLITAN_RAILWAY_STATION_STATION'], 'column_names_original': [[-1, '*'], [0, 'STATION_NMP'], [0, 'RIDINGQ'], [0, 'STOPOVERR']], 'column_types': ['text', 'text', 'number', 'number']}
# {'db_id': 'publicdata_transportation_1207', 'table_names_original': ['MONTHLY_STS_ILLEGAL_PARKING_CONTROL_GANGDONG_GU_SEOUL'], 'column_names_original': [[-1, '*'], [0, 'TRIAL_NAME'], [0, 'CITIES_AND_COUNTIES'], [0, 'CRACKDOWN'], [0, 'NUMBER_OF_CRACKDOWNS']], 'column_types': ['text', 'text', 'text', 'text', 'number']}
# {'db_id': 'publicdata_transportation_2338', 'table_names_original': ['STS_GGBC_VE_TAX_DEFERRED_VE_LICENSE_PLATE_RETENTION'], 'column_names_original': [[-1, '*'], [0, 'SERIAL_NUMP'], [0, 'RETENTION_DTQ'], [0, 'VEHICLE_NUMR'], [0, 'NUM_ARREARSS'], [0, 'AMT_ARREARST'], [0, 'PLACE_DETENTIONU'], [0, 'RETURN_DTV']], 'column_types': ['text', 'number', 'time', 'text', 'number', 'number', 'text', 'time']}
# {'db_id': 'publicdata_transportation_6671', 'table_names_original': ['STS_KORAIL_FREIGHT_STATION'], 'column_names_original': [[-1, '*'], [0, 'AREAX'], [0, 'STATION_NMY']], 'column_types': ['text', 'text', 'text']}
# {'db_id': 'publicdata_transportation_6389', 'table_names_original': ['STS_R_VESSELS_UNDER_MOF_VESSELS_ACT'], 'column_names_original': [[-1, '*'], [0, '_WALL_MONTHLYS'], [0, 'TONE_CLAST'], [0, 'SORTATIONU'], [0, 'SUM_TOTALV'], [0, 'Y_5_UNDERW'], [0, 'Y_5_10_UNDERX'], [0, 'Y_10_15_UNDERY'], [0, 'Y_15_20_UNDERZ'], [0, 'Y_20_25_UNDERA'], [0, 'Y_25_30_UNDERB'], [0, 'Y_30_35_UNDERC'], [0, 'Y_35_MORED']], 'column_types': ['text', 'text', 'text', 'text', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number']}
# {'db_id': 'publicdata_transportation_10354', 'table_names_original': ['EX_HI_PASS_TERMINAL_S_OFFICE_INFO', 'HIGH_PASS_UTILIZATION_RATIO_EX_S_OFFICE'], 'column_names_original': [[-1, '*'], [0, 'HEADQUARTERS'], [0, 'NAME'], [0, 'BUSINESS_CALL'], [0, 'PHONE_NUMBER'], [0, 'FAX_NUMBER'], [0, 'ZIP_CODE'], [0, 'ADDRESS'], [1, 'DIVISION'], [1, 'BUSINESS_OFFICE'], [1, 'HIGH_PASS_USAGE_RATE'], [1, 'NOTE']], 'column_types': ['text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'number', 'text']}
# {'db_id': 'publicdata_transportation_11061', 'table_names_original': ['SELMETRO_ELEVATOR_I_INFO', 'SELMETRO_HISTORICAL_CULTURE_ARTS_DECORATION_STS'], 'column_names_original': [[-1, '*'], [0, 'ANNUAL'], [0, 'LINE'], [0, 'STATION_NAME'], [0, 'EQUIPMENT'], [0, 'AORY'], [0, 'ELEVATOR_NUMBER'], [0, 'OPERATING_SECTION'], [0, 'INSTALLATION_LOCATION'], [1, 'LINE'], [1, 'STATION_NAME'], [1, 'LOCATION'], [1, 'ORNAMENT'], [1, 'TYPE'], [1, 'WRITER'], [1, 'QUANTITY']], 'column_types': ['text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'number']}
# {'db_id': 'publicdata_education_1654', 'table_names_original': ['DETAILS_BUSAN_HUMAN_RESOURCES_DEV_INSTITUTE_EDU_O_SYS'], 'column_names_original': [[-1, '*'], [0, 'COURSE_NUMBER'], [0, 'EVALUATION_ITEM_ID'], [0, 'COURSE_ORDER_ID'], [0, 'EVALUATION_ITEM_CODE'], [0, 'EVALUATION_PORT'], [0, 'EVALUATION_ITEM'], [0, 'TOTAL_SCORE'], [0, 'AUTHOR_NUMBER'], [0, 'DATE_OF_ISSUE'], [0, 'EVALUATION']], 'column_types': ['text', 'number', 'number', 'text', 'number', 'text', 'number', 'number', 'number', 'time', 'number']}
# {'db_id': 'publicdata_education_390', 'table_names_original': ['APP_LIBRARY_CLUBS_BORYEONG_CHUNGNAM'], 'column_names_original': [[-1, '*'], [0, 'APPLICATION_DATE'], [0, 'APPLICATION_TIME'], [0, 'MEETING_NAME'], [0, 'PURPOSE_OF_USE'], [0, 'DATA_STANDARD_DATE']], 'column_types': ['text', 'time', 'text', 'text', 'text', 'time']}
# {'db_id': 'publicdata_education_2527', 'table_names_original': ['KRIVET_AUTHORIZED_PRIVATE_Q_REG_STS'], 'column_names_original': [[-1, '*'], [0, 'COMPETENT_MINISTRIESE'], [0, 'QUALIFICATION_ITEMSF'], [0, 'RATINGG'], [0, 'QUALIFICATION_MANAGERH'], [0, 'A_V_P_B_J'], [0, 'E_A_V_P_K'], [0, 'START_STOMATAL_PERIODK'], [0, 'E_O_S_P_M']], 'column_types': ['text', 'text', 'text', 'text', 'text', 'time', 'time', 'time', 'time']}
# {'db_id': 'publicdata_education_4603', 'table_names_original': ['KOSAF_YOUTH_EDU_MNG_ASSIGNMENT_AMT_DETAILS'], 'column_names_original': [[-1, '*'], [0, 'PRODUCT_NMJ'], [0, 'ALLOC_YEARK'], [0, 'ASSIGNMENT_CLASL'], [0, 'ASSIGNMENT_SERIAL_NUMM'], [0, 'NM_UNIVERSITYN'], [0, 'TOTAL_ALLOC_AMTO'], [0, 'A_A_1_S_Z'], [0, 'A_A_2_S_ZZ'], [0, 'ALLOC_DTR']], 'column_types': ['text', 'text', 'number', 'text', 'number', 'text', 'number', 'number', 'number', 'time']}
# {'db_id': 'publicdata_education_4675', 'table_names_original': ['BASIC_HISTORY_N_TREASURY_I_PROFIT_KOSAF_YOUTH_EDU_MNG'], 'column_names_original': [[-1, '*'], [0, 'PRODUCT_CDN'], [0, 'YEARO'], [0, 'SEMESTERP'], [0, 'UNIVERSITY_CDQ'], [0, 'INTEREST_ACCRUAL_DTR'], [0, 'DETAILED_DT_TIME_CHANGES'], [0, 'INTEREST_INCOME_AMTT'], [0, 'DT_TIME_INITIAL_REU'], [0, 'LAST_CHANGE_DT_TIMEV']], 'column_types': ['text', 'text', 'number', 'number', 'text', 'time', 'time', 'number', 'time', 'time']}
# {'db_id': 'publicdata_education_4683', 'table_names_original': ['KOSAF_STATEMENT_FINANCIAL_POSITION'], 'column_names_original': [[-1, '*'], [0, 'SJD'], [0, 'E_13TH_PARTY_ORIGIN_1E'], [0, 'E_13TH_PARTY_ORIGIN_2F'], [0, 'E_1_E_O_1_ZZ'], [0, 'E_1_E_O_2_VA']], 'column_types': ['text', 'text', 'number', 'number', 'number', 'number']}
# {'db_id': 'publicdata_education_4544', 'table_names_original': ['C_STS_MENTORING_MENTORS_COLLEGE_STUDENTS_KOSAF_SOCIAL_LEADER'], 'column_names_original': [[-1, '*'], [0, 'NUML'], [0, 'YEARM'], [0, 'GENDERN'], [0, 'SPECIALIZED_DEPARTMENTO'], [0, 'PARTICIPANT_CLASP']], 'column_types': ['text', 'number', 'number', 'text', 'text', 'text']}
# {'db_id': 'publicdata_education_5088', 'table_names_original': ['HRDK_HRD4U_CONTENT_STS'], 'column_names_original': [[-1, '*'], [0, 'CONTENT_TYPEW'], [0, 'CONTENT_FIELDX'], [0, 'CONTENT_NMY'], [0, 'NEXT_NMZ'], [0, 'PRODUCTION_DTA'], [0, 'SOURCESB']], 'column_types': ['text', 'text', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'publicdata_education_6575', 'table_names_original': ['D_P_I_L_K_L_A_K_C_I_K_L_I_AM'], 'column_names_original': [[-1, '*'], [0, 'NUMJ'], [0, 'RE_DTK'], [0, 'PRODUCER_CDL'], [0, 'ORAL_INF_CONNECTION_NUMM']], 'column_types': ['text', 'number', 'text', 'text', 'text']}
# {'db_id': 'publicdata_education_5093', 'table_names_original': ['GBE_GB_YECHEON_O_EDU_C_STS_HAGWON'], 'column_names_original': [[-1, '*'], [0, 'SORTATIONE'], [0, 'NUMF'], [0, 'NM_ACADEMYG'], [0, 'ADDRESSH'], [0, 'PHONE_NUMI']], 'column_types': ['text', 'text', 'number', 'text', 'text', 'text']}
# {'db_id': 'publicdata_education_5473', 'table_names_original': ['STS_SU_KASFO_HAPPY_DORMITORY_PRO'], 'column_names_original': [[-1, '*'], [0, 'YEARG'], [0, 'SCHOOL_NM_BUSINESS_NMH'], [0, 'CPI'], [0, 'T_P_C_1_M_W_Q'], [0, 'METER_SQUARE_FLOOR_AREAK'], [0, 'P_F_F_R_S'], [0, 'FINANCIAL_HOUSING_FUNDM'], [0, 'F_R_T_U'], [0, 'GOVERNMENT_SUBSIDYO'], [0, 'PROGRESS_STAP']], 'column_types': ['text', 'number', 'text', 'number', 'number', 'number', 'number', 'number', 'number', 'text', 'text']}
# {'db_id': 'publicdata_education_5329', 'table_names_original': ['KASFO_TRAINING_PRO_TRAINING_MNG_TRAINING_INFO'], 'column_names_original': [[-1, '*'], [0, 'TRAINING_NUMJ'], [0, 'HOTEL_ORDERK'], [0, 'HOTEL_UNIQUE_NUML'], [0, 'ROOM_NUMM'], [0, 'DISCLOSURE_STAN'], [0, 'TYPEO'], [0, 'CPP'], [0, 'NUM_APPLICANTSQ'], [0, 'GENDER_DISTINCTIONR'], [0, 'PRIVATE_ROOM_STAS'], [0, 'DT_ENTRYT'], [0, 'INPUT_PERSONU'], [0, 'REVISION_DTV']], 'column_types': ['text', 'text', 'number', 'number', 'number', 'text', 'number', 'number', 'number', 'text', 'text', 'text', 'text', 'text']}
# {'db_id': 'publicdata_education_6709', 'table_names_original': ['GWE_TEACHING_CNT_STS'], 'column_names_original': [[-1, '*'], [0, 'NM_TEACHING_CALLA'], [0, 'NM_INSTRUCTORB'], [0, 'RE_STAC'], [0, 'PHONE_NUMD'], [0, 'TEACHING_ADDRESSE'], [0, 'NUM_PEOPLE_TEMPORARY_CPF'], [0, 'TOTAL_QUOTAG'], [0, 'FIELD_CLASH'], [0, 'TEACHING_SERIESI'], [0, 'TEACHING_COURSEJ'], [0, 'TEACHING_CLASSK'], [0, 'PERIOD_INSTRUCTIONL'], [0, 'TOTAL_TRAINING_HOURSM'], [0, 'TEACHING_FEEN'], [0, 'TEACHING_FEE_PER_HOURO'], [0, 'TEXTBOOK_EXPENSESP'], [0, 'MOCK_TEST_FEEQ'], [0, 'MATERIAL_COSTR'], [0, 'SCHOOL_MEAL_EXPENSESS'], [0, 'COST_SNACKST'], [0, 'DORMITORY_FEEU'], [0, 'COST_VEHICLEV'], [0, 'OTHER_EXPENSESW'], [0, 'CLOTHING_COSTX'], [0, 'TOTAL_OTHER_EXPENSESY'], [0, 'TOTAL_COST_TEACHINGZ'], [0, 'T_T_F_P_H_J']], 'column_types': ['text', 'text', 'text', 'text', 'text', 'text', 'number', 'number', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'text', 'text']}
# {'db_id': 'publicdata_education_6711', 'table_names_original': ['GWE_SCHOOL_STS'], 'column_names_original': [[-1, '*'], [0, 'JURISDICTIONG'], [0, 'NM_SCHOOLH'], [0, 'ADDRESSI'], [0, 'PHONE_NUMJ'], [0, 'HOMEPAGEK']], 'column_types': ['text', 'text', 'text', 'text', 'number', 'text']}
# {'db_id': 'publicdata_education_13524', 'table_names_original': ['LIST_GGIC_POPULAR_BOOKS', 'GGGJ_BOOK_LOAN_INFO_STS'], 'column_names_original': [[-1, '*'], [0, 'NUMQ'], [0, 'BOOK_NMR'], [0, 'AUTHORS'], [0, 'PUBLISHING_HOUSET'], [0, 'YEAR_ISSUE_YEARU'], [0, 'NUM_LOANSV'], [0, 'BASE_QUARTERW'], [1, 'CITY_COUNTY_NMM'], [1, 'LIBRARY_NMN'], [1, 'BOOK_NMO'], [1, 'I_S_B_N_Q'], [1, 'C_S_K_D_C_M_RC'], [1, 'DT_TIME_LOANR'], [1, 'DATA_BASE_DTS']], 'column_types': ['text', 'number', 'text', 'text', 'text', 'number', 'number', 'text', 'text', 'text', 'text', 'text', 'number', 'time', 'time']}

# %%
# 위에서 추출한 schema_info에서 db_id를 key, table_names_original과 column_names_original, column_types를 value로 해서 dictionary를 만듬

schema_val_dict = {}

for schema in schema_val_info:
  db_id = schema['db_id']
  schema_val_dict[db_id] = {
      'table_names_original': schema['table_names_original'][0],
      'column_names_original': [col[1] for col in schema['column_names_original']],
      'column_types': schema['column_types']
  }

# %%
for key, value in schema_val_dict.items():
  print(f"Key: {key}")
  print(f"Value: {value}")
  print("-" * 20)
# Out:
# Key: seouldata_healthcare_733
# Value: {'table_names_original': 'TB_PHARMACY_OPERATE_INFO', 'column_names_original': ['*', 'HPID', 'DUTYADDR', 'DUTYNAME', 'DUTYTEL1', 'DUTYTIME1C', 'DUTYTIME2C', 'DUTYTIME3C', 'DUTYTIME4C', 'DUTYTIME5C', 'DUTYTIME6C', 'DUTYTIME7C', 'DUTYTIME8C', 'DUTYTIME1S', 'DUTYTIME2S', 'DUTYTIME3S', 'DUTYTIME4S', 'DUTYTIME5S', 'DUTYTIME6S', 'DUTYTIME7S', 'DUTYTIME8S', 'POSTCDN1', 'POSTCDN2', 'WGS84LON', 'WGS84LAT', 'WORK_DTTM'], 'column_types': ['text', 'text', 'text', 'text', 'text', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'time']}
# --------------------
# Key: seouldata_healthcare_1353
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_020302_D_D', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'SITETEL', 'SITEAREA', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEGBN', 'UPDATEDT', 'UPTAENM', 'X', 'Y', 'RGTMBDSNO'], 'column_types': ['text', 'number', 'number', 'time', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_1485
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_020302_M_P', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'APVCANCELYMD', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'CLGSTDT', 'CLGENDDT', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEGBN', 'UPDATEDT', 'X', 'Y', 'LINDJOBGBNNM', 'LINDPRCBGBNNM', 'LINDSEQNO', 'RGTMBDSNO', 'TOTEPNUM'], 'column_types': ['text', 'number', 'number', 'time', 'text', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'number', 'text']}
# --------------------
# Key: seouldata_healthcare_2398
# Value: {'table_names_original': 'YS_FOOD_COLLECT_CHECK', 'column_names_original': ['*', 'CGG_CODE', 'SNT_COB_CODE', 'SNT_COB_NM', 'PLN_SE_CODE', 'PLN_SE_NM', 'CHK_PLN_NM', 'COL_PLN_NM', 'COL_WHY_CODE', 'UPSO_NM', 'ATCL_GUN_NM', 'ATCL_NM', 'PRDT_NM', 'EDF_NM', 'RM_NM', 'PDT_UPSO_NM', 'COL_YMD', 'COL_QUA', 'PRDT_SIZE', 'LOT_NO', 'PRDT_YUTONG_DLN', 'YUTONG_DLN_PRD_YMD_FROM', 'DEPO_STATE_CODE', 'BCE_CODE', 'CHD_SMBL_FD_KD_CODE', 'FACTORY_NM', 'NTN', 'ISP_SE', 'ISP_REQ_YMD', 'ISP_RT_REPLY_YMD', 'COL_ISP_RT_GBN', 'COL_ISP_SE', 'COL_PLC_SE', 'COL_PDT_DEAL', 'GNT_NO'], 'column_types': ['text', 'number', 'number', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'time', 'number', 'text', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'time', 'time', 'text', 'text', 'text', 'text', 'number']}
# --------------------
# Key: seouldata_healthcare_2088
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_072211_J_G', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVCANCELYMD', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'CLGSTDT', 'CLGENDDT', 'ROPNYMD', 'SITETEL', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'BPLCNM', 'LASTMODTS', 'UPDATEGBN', 'UPTAENM', 'Y', 'MANEIPCNT', 'WMEIPCNT', 'TRDPJUBNSENM', 'LVSENM', 'WTRSPLYFACILSENM', 'TOTEPNUM', 'HOFFEPCNT', 'FCTYOWKEPCNT', 'FCTYSILJOBEPCNT', 'MULTUSNUPSOYN', 'FACILTOTSCP', 'JTUPSOASGNNO', 'JTUPSOMAINEDF', 'HOMEPAGE'], 'column_types': ['text', 'number', 'text', 'text', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'number', 'number', 'text', 'text', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_2459
# Value: {'table_names_original': 'SB_PUBLIC_HYGIENE_BIZ_PUBLIC_USE_FACILITY', 'column_names_original': ['*', 'CGG_CODE', 'SNT_COB_CODE', 'YY', 'UPSO_SNO', 'UPSO_GSL_YMD', 'UPSO_NM', 'BMAN_STDT', 'BUP_NM', 'SITE_STDT', 'ADMDNG_NM', 'DCB_YMD', 'SNT_UPTAE_NM', 'ED_FIN_YMD', 'YANGSIL', 'CHAIR_NUM', 'BALHANSIL_YN', 'WASHMC_NUM', 'PERM_NT_NO', 'KOR_FRGNR_GBN', 'NTN'], 'column_types': ['text', 'number', 'number', 'number', 'number', 'time', 'text', 'time', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_2654
# Value: {'table_names_original': 'GD_ADMIN_MESURE_PUBLIC', 'column_names_original': ['*', 'CGG_CODE', 'ADM_DISPO_YMD', 'GNT_NO', 'SNT_COB_NM', 'SNT_UPTAE_NM', 'UPSO_NM', 'SITE_ADDR_RD', 'SITE_ADDR', 'DRT_INSP_YMD', 'ADMM_STATE', 'DISPO_CTN', 'BAS_LAW', 'VIOR_YMD', 'DISPO_CTN_DT', 'DISPO_GIGAN', 'INSP_GBN_CODE', 'TRDP_AREA'], 'column_types': ['text', 'number', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'time', 'text', 'text', 'text', 'time', 'text', 'text', 'text', 'number']}
# --------------------
# Key: seouldata_healthcare_2677
# Value: {'table_names_original': 'SC_MODEL_RESTAURANT_DESIGNATE', 'column_names_original': ['*', 'SC_RESTAURANT_CGG_CODE', 'ASGN_YY', 'SC_RESTAURANT_ASGN_SNO', 'SC_RESTAURANT_APPL_YMD', 'UPSO_NM', 'SC_RESTAURANT_SITE_ADDR_RD', 'SC_RESTAURANT_SITE_ADDR', 'SC_RESTAURANT_PERM_NT_NO', 'SNT_UPTAE_NM', 'MAIN_EDF', 'TRDP_AREA', 'ADMDNG_NM', 'UPSO_SITE_TELNO'], 'column_types': ['text', 'number', 'time', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_3349
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_072206_S_P', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'APVCANCELYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DTLSTATENM', 'DCBYMD', 'CLGSTDT', 'CLGENDDT', 'ROPNYMD', 'SITETEL', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'BPLCNM', 'LASTMODTS', 'UPDATEGBN', 'UPDATEDT', 'UPTAENM', 'Y', 'LINDJOBGBNNM', 'LINDPRCBGBNNM', 'LINDSEQNO'], 'column_types': ['text', 'number', 'number', 'time', 'text', 'number', 'text', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_4595
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_010202_G_D', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'APVCANCELYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'CLGENDDT', 'ROPNYMD', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEGBN', 'UPDATEDT', 'UPTAENM', 'X', 'Y', 'MEDKIND', 'SJYN', 'TOTSCP', 'TRDSCP'], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_397
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_010108', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'APVCANCELYMD', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'CLGSTDT', 'SITETEL', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'UPDATEGBN', 'UPDATEDT', 'UPTAENM', 'X', 'Y', 'METRORGASSRNM', 'HSTRMNUM', 'SICBNUM', 'TOTAR', 'MEDEXTRITEMSCN', 'ASGNCANCELYMD', 'MITMDCDEPNM', 'EMERCARSPEC', 'EMERCARGEN', 'TOTEPNUM', 'RESCNT'], 'column_types': ['text', 'number', 'text', 'time', 'text', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_876
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_072401', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'APVCANCELYMD', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'CLGENDDT', 'ROPNYMD', 'SITETEL', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEGBN', 'UPDATEDT', 'X', 'Y', 'CULWRKRSENM', 'REGNSENM', 'NEARENVNM', 'INSURORGNM', 'BDNGSRVNM', 'STROOMCNT', 'CNSTYAREA', 'ENGSTNTRNMNM', 'SHPCNT', 'SHPINFO'], 'column_types': ['text', 'number', 'text', 'time', 'time', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_1768
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_010105_G_J', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'APVCANCELYMD', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'CLGSTDT', 'ROPNYMD', 'SITETEL', 'SITEAREA', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEGBN', 'UPDATEDT', 'X', 'Y'], 'column_types': ['text', 'number', 'text', 'time', 'time', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_1365
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_010102_G_S', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'CLGSTDT', 'CLGENDDT', 'SITETEL', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'BPLCNM', 'LASTMODTS', 'UPDATEDT', 'UPTAENM', 'X', 'Y', 'METRPNUM', 'HSTRMNUM', 'SICBNUM', 'TOTAR', 'MEDEXTRITEMSCN', 'MEDEXTRITEMSCNNM', 'MITMDCASGNTYPE', 'TOTEPNUM', 'RESCNT', 'PMTBEDNUM', 'FRSTASGNYMD'], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'text', 'time', 'time', 'time', 'text', 'number', 'text', 'text', 'text', 'number', 'time', 'text', 'number', 'number', 'text', 'text', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_2286
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_072219_Y_D', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'APVCANCELYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DTLSTATENM', 'CLGENDDT', 'ROPNYMD', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEDT', 'UPTAENM', 'X', 'Y', 'SNTUPTAENM', 'MANEIPCNT', 'WMEIPCNT', 'TRDPJUBNSENM', 'WTRSPLYFACILSENM', 'TOTEPNUM', 'FCTYSILJOBEPCNT', 'FCTYPDTJOBEPCNT', 'BDNGOWNSENM', 'ISREAM', 'MULTUSNUPSOYN', 'FACILTOTSCP', 'JTUPSOASGNNO', 'JTUPSOMAINEDF', 'HOMEPAGE'], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'number', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_1545
# Value: {'table_names_original': 'GD_TN_BBS9', 'column_names_original': ['*', 'NAME', 'ADDR', 'PHONE', 'ETC', 'LANGUAGE'], 'column_types': ['text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_4669
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_072213_G_J', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'CLGSTDT', 'ROPNYMD', 'SITETEL', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPTAENM', 'X', 'Y', 'WMEIPCNT', 'TRDPJUBNSENM', 'LVSENM', 'WTRSPLYFACILSENM', 'TOTEPNUM', 'HOFFEPCNT', 'FCTYOWKEPCNT', 'FCTYSILJOBEPCNT', 'BDNGOWNSENM', 'ISREAM', 'MONAM', 'FACILTOTSCP', 'JTUPSOMAINEDF', 'HOMEPAGE'], 'column_types': ['text', 'number', 'text', 'time', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_70
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_020301', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'APVCANCELYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'CLGSTDT', 'CLGENDDT', 'SITETEL', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEDT', 'UPTAENM', 'Y', 'LINDJOBGBNNM', 'LINDPRCBGBNNM', 'LINDSEQNO', 'RGTMBDSNO', 'TOTEPNUM'], 'column_types': ['text', 'number', 'number', 'time', 'text', 'number', 'text', 'number', 'text', 'time', 'time', 'time', 'text', 'number', 'text', 'text', 'text', 'number', 'text', 'number', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'number']}
# --------------------
# Key: seouldata_healthcare_405
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_010201', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNUMBER', 'APVPERMYMD', 'APVCANCELYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'CLGSTDT', 'CLGENDDT', 'SITETEL', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEGBN', 'UPDATEDT', 'UPTAENM', 'Y', 'SAMPLENSNUM', 'PUPILDISTMEASNUM', 'DEFPTRFRTGGNUM', 'GLSWASHERNUM'], 'column_types': ['text', 'number', 'text', 'time', 'time', 'number', 'text', 'number', 'text', 'time', 'time', 'time', 'text', 'text', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_2403
# Value: {'table_names_original': 'GN_FOOD_COLLECT_CHECK_HYGIENE_BIZ', 'column_names_original': ['*', 'CGG_CODE', 'SNT_COB_CODE', 'SNT_COB_NM', 'PLN_SE_CODE', 'PLN_SE_NM', 'CHK_PLN_NM', 'COL_PLN_NM', 'COL_PRFDOC_NO', 'COL_WHY_CODE', 'UPSO_NM', 'ATCL_GUN_CODE', 'ATCL_GUN_NM', 'ATCL_NM', 'PRDT_NM', 'RM_NM', 'PDT_UPSO_NM', 'COL_YMD', 'COL_QUA', 'PRDT_SIZE', 'COL_QY_IPT', 'PRD_YMD', 'PRDT_YUTONG_DLN', 'YUTONG_DLN_PRD_YMD_FROM', 'BCE_CODE', 'FACTORY_NM', 'NATIV_FRGNR_SE', 'NTN', 'ISP_SE', 'ISP_RT_REPLY_YMD', 'COL_ISP_RT_GBN', 'DEAL_SE', 'COL_ISP_SE', 'CTL_REGN_SE', 'COL_PLC_SE', 'DEAL_RT', 'COL_PDT_DEAL', 'GNT_NO', 'DRT_INSP_YMD'], 'column_types': ['text', 'number', 'number', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'time', 'number', 'text', 'text', 'time', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'time']}
# --------------------
# Key: seouldata_healthcare_2212
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_072203_G_A', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'ROPNYMD', 'SITETEL', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'BPLCNM', 'LASTMODTS', 'UPDATEGBN', 'UPTAENM', 'X', 'Y', 'SNTUPTAENM', 'MANEIPCNT', 'WMEIPCNT', 'TRDPJUBNSENM', 'WTRSPLYFACILSENM', 'TOTEPNUM', 'HOFFEPCNT', 'FCTYOWKEPCNT', 'FCTYSILJOBEPCNT', 'FCTYPDTJOBEPCNT', 'BDNGOWNSENM', 'ISREAM', 'MONAM', 'FACILTOTSCP', 'JTUPSOASGNNO', 'JTUPSOMAINEDF'], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'number', 'text', 'text', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_3094
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_072302_Y_S', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'CLGSTDT', 'CLGENDDT', 'ROPNYMD', 'SITETEL', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEGBN', 'UPDATEDT', 'UPTAENM', 'X', 'Y', 'SNTUPTAENM', 'MANEIPCNT', 'WMEIPCNT', 'LVSENM', 'WTRSPLYFACILSENM', 'TOTEPNUM', 'HOFFEPCNT', 'FCTYOWKEPCNT', 'FCTYSILJOBEPCNT', 'BDNGOWNSENM', 'ISREAM', 'MONAM', 'FACILTOTSCP', 'JTUPSOASGNNO', 'JTUPSOMAINEDF', 'HOMEPAGE'], 'column_types': ['text', 'number', 'text', 'time', 'number', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_3864
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_072202_D_D', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'APVCANCELYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'CLGENDDT', 'SITETEL', 'SITEAREA', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'UPDATEGBN', 'UPDATEDT', 'UPTAENM', 'X', 'Y', 'MANEIPCNT', 'WMEIPCNT', 'WTRSPLYFACILSENM', 'TOTEPNUM', 'HOFFEPCNT', 'FCTYOWKEPCNT', 'FCTYPDTJOBEPCNT', 'BDNGOWNSENM', 'ISREAM', 'MONAM', 'FACILTOTSCP', 'JTUPSOASGNNO', 'JTUPSOMAINEDF', 'HOMEPAGE'], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_5400
# Value: {'table_names_original': 'TB_RPRT_CLIC_HOSP', 'column_names_original': ['*', 'YKIHO', 'SEQNO', 'SGGUNM', 'YADMNM', 'RECUCLCD', 'CLICADDR', 'TELNO', 'CV19SPCMGATEXECYN', 'ADTSTADD', 'SUNMGTHRTXT', 'MONMGTHRTXT', 'TUEMGTHRTXT', 'WEDMGTHRTXT', 'THUMGTHRTXT', 'FRIMGTHRTXT', 'SATMGTHRTXT', 'XPOS', 'XPOSWGS84', 'YPOS', 'YPOSWGS84'], 'column_types': ['text', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'text', 'time', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number']}
# --------------------
# Key: seouldata_healthcare_683
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_010202', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'TRDSTATENM', 'DTLSTATEGBN', 'DCBYMD', 'CLGSTDT', 'CLGENDDT', 'ROPNYMD', 'SITETEL', 'SITEAREA', 'SITEPOSTNO', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEGBN', 'UPDATEDT', 'X', 'Y', 'MEDKIND', 'SJYN'], 'column_types': ['text', 'number', 'text', 'time', 'text', 'text', 'time', 'time', 'time', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_1761
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_072203_D_D', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'APVCANCELYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DTLSTATENM', 'DCBYMD', 'CLGSTDT', 'CLGENDDT', 'ROPNYMD', 'SITETEL', 'SITEAREA', 'BPLCNM', 'LASTMODTS', 'UPDATEGBN', 'UPDATEDT', 'UPTAENM', 'X', 'Y', 'SNTUPTAENM', 'MANEIPCNT', 'WMEIPCNT', 'TRDPJUBNSENM', 'LVSENM', 'WTRSPLYFACILSENM', 'FCTYOWKEPCNT', 'FCTYSILJOBEPCNT', 'FCTYPDTJOBEPCNT', 'BDNGOWNSENM', 'ISREAM', 'MONAM', 'FACILTOTSCP', 'JTUPSOMAINEDF', 'HOMEPAGE'], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'text', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_1515
# Value: {'table_names_original': 'GANGSEO_ADMIN_MESURE', 'column_names_original': ['*', 'CGG_CODE', 'ADM_DISPO_YMD', 'GNT_NO', 'SNT_COB_NM', 'SNT_UPTAE_NM', 'UPSO_NM', 'SITE_ADDR_RD', 'SITE_ADDR', 'DRT_INSP_YMD', 'ADMM_STATE', 'DISPO_CTN', 'BAS_LAW', 'VIOL_CN', 'DISPO_CTN_DT', 'NT_GBN_CODE', 'JB_ORG', 'TAKE_YMD', 'TRDP_AREA'], 'column_types': ['text', 'number', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'time', 'number']}
# --------------------
# Key: seouldata_healthcare_2602
# Value: {'table_names_original': 'SP_ADMIN_MESURE_FOOD', 'column_names_original': ['*', 'CGG_CODE', 'ADM_DISPO_YMD', 'GNT_NO', 'SNT_COB_NM', 'SNT_UPTAE_NM', 'UPSO_NM', 'SITE_ADDR', 'DRT_INSP_YMD', 'ADMM_STATE', 'DISPO_CTN', 'VIOR_SORT', 'BAS_LAW', 'VIOR_YMD', 'VIOL_CN', 'DISPO_CTN_DT', 'DISPO_GIGAN', 'NT_GBN_CODE', 'TRDP_AREA', 'MNG_GBN_NM'], 'column_types': ['text', 'number', 'number', 'number', 'text', 'text', 'text', 'text', 'time', 'text', 'text', 'text', 'text', 'time', 'text', 'text', 'text', 'text', 'number', 'text']}
# --------------------
# Key: seouldata_healthcare_2313
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_010203_S_C', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'CLGSTDT', 'ROPNYMD', 'SITETEL', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEDT', 'X', 'Y', 'MEDKIND', 'TOTSCP', 'TRDSCP'], 'column_types': ['text', 'number', 'text', 'time', 'number', 'text', 'number', 'text', 'time', 'time', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'number', 'time', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_3867
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_072302_D_J', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'APVCANCELYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DTLSTATENM', 'DCBYMD', 'CLGSTDT', 'CLGENDDT', 'ROPNYMD', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEGBN', 'UPDATEDT', 'UPTAENM', 'X', 'Y', 'SNTUPTAENM', 'MANEIPCNT', 'WMEIPCNT', 'TRDPJUBNSENM', 'WTRSPLYFACILSENM', 'FCTYOWKEPCNT', 'FCTYPDTJOBEPCNT', 'BDNGOWNSENM', 'ISREAM', 'MONAM', 'FACILTOTSCP', 'JTUPSOASGNNO', 'JTUPSOMAINEDF', 'HOMEPAGE'], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'text', 'text', 'time', 'text', 'text', 'text', 'number', 'number', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_5338
# Value: {'table_names_original': 'GB_GLSS_BSSH_STTUS_INFO', 'column_names_original': ['*', 'GLSS_BBSH_STTUS', 'BPLC_LOCPLC', 'BPCL_TELNO'], 'column_types': ['text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_3358
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_072301_Y_D', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'APVCANCELYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DTLSTATENM', 'DCBYMD', 'CLGENDDT', 'ROPNYMD', 'SITETEL', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEDT', 'X', 'Y', 'SNTUPTAENM', 'MANEIPCNT', 'TRDPJUBNSENM', 'LVSENM', 'WTRSPLYFACILSENM', 'TOTEPNUM', 'HOFFEPCNT', 'FCTYOWKEPCNT', 'FCTYPDTJOBEPCNT', 'BDNGOWNSENM', 'FACILTOTSCP'], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'text', 'text', 'time', 'text', 'text', 'text', 'number', 'number', 'text', 'text', 'number', 'text', 'number', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_2191
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_072203_D_J', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'CLGSTDT', 'CLGENDDT', 'ROPNYMD', 'SITETEL', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEGBN', 'UPDATEDT', 'UPTAENM', 'X', 'Y', 'SNTUPTAENM', 'MANEIPCNT', 'WMEIPCNT', 'TRDPJUBNSENM', 'LVSENM', 'HOFFEPCNT', 'FCTYPDTJOBEPCNT', 'BDNGOWNSENM', 'MONAM', 'FACILTOTSCP', 'JTUPSOASGNNO', 'HOMEPAGE'], 'column_types': ['text', 'number', 'text', 'time', 'number', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_1962
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_072211_J_N', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'APVCANCELYMD', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'CLGSTDT', 'SITETEL', 'SITEAREA', 'SITEWHLADDR', 'BPLCNM', 'LASTMODTS', 'X', 'Y', 'SNTUPTAENM', 'MANEIPCNT', 'WMEIPCNT', 'LVSENM', 'HOFFEPCNT', 'FCTYSILJOBEPCNT', 'ISREAM', 'MULTUSNUPSOYN', 'JTUPSOASGNNO', 'HOMEPAGE'], 'column_types': ['text', 'number', 'text', 'time', 'text', 'text', 'number', 'text', 'time', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_3651
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_093011_Y_S', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'APVCANCELYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'CLGSTDT', 'CLGENDDT', 'SITETEL', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEGBN', 'UPDATEDT', 'X', 'Y', 'OFEAR', 'DISFETVEHGARAR', 'HNDUSESTLZNUM', 'DYNPWSPRAYNUM', 'HDOPTDSPRAYNUM', 'PROTGLSNUM', 'PROTUSECLOTNUM', 'VACUCLERNUM'], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_3260
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_072218_G_D', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'APVCANCELYMD', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'CLGSTDT', 'ROPNYMD', 'SITETEL', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'BPLCNM', 'LASTMODTS', 'UPDATEGBN', 'X', 'Y', 'MANEIPCNT', 'WMEIPCNT', 'TRDPJUBNSENM', 'LVSENM', 'WTRSPLYFACILSENM', 'FCTYOWKEPCNT', 'FCTYSILJOBEPCNT', 'FCTYPDTJOBEPCNT', 'ISREAM', 'MONAM', 'FACILTOTSCP', 'JTUPSOMAINEDF', 'HOMEPAGE'], 'column_types': ['text', 'number', 'text', 'time', 'text', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_3315
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_072202_S_C', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DTLSTATENM', 'DCBYMD', 'CLGSTDT', 'CLGENDDT', 'ROPNYMD', 'SITETEL', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'UPDATEGBN', 'UPTAENM', 'X', 'Y', 'MANEIPCNT', 'WMEIPCNT', 'LVSENM', 'WTRSPLYFACILSENM', 'TOTEPNUM', 'FCTYOWKEPCNT', 'FCTYSILJOBEPCNT', 'FCTYPDTJOBEPCNT', 'ISREAM', 'MONAM', 'JTUPSOASGNNO', 'JTUPSOMAINEDF', 'HOMEPAGE'], 'column_types': ['text', 'number', 'text', 'time', 'number', 'text', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_1816
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_010106_J_G', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVCANCELYMD', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'SITETEL', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'BPLCNM', 'LASTMODTS', 'UPDATEGBN', 'UPDATEDT', 'UPTAENM', 'Y', 'PHARMTRDAR', 'ASGNYMD'], 'column_types': ['text', 'number', 'text', 'text', 'text', 'number', 'text', 'time', 'text', 'number', 'text', 'text', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'time']}
# --------------------
# Key: seouldata_healthcare_1740
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_072211_G_R', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'CLGENDDT', 'ROPNYMD', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEDT', 'UPTAENM', 'X', 'Y', 'SNTUPTAENM', 'MANEIPCNT', 'WMEIPCNT', 'TRDPJUBNSENM', 'LVSENM', 'WTRSPLYFACILSENM', 'HOFFEPCNT', 'FCTYSILJOBEPCNT', 'FCTYPDTJOBEPCNT', 'BDNGOWNSENM', 'FACILTOTSCP', 'HOMEPAGE'], 'column_types': ['text', 'number', 'text', 'time', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'number', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_2102
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_010106_G_J', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'APVCANCELYMD', 'DTLSTATEGBN', 'DTLSTATENM', 'ROPNYMD', 'SITETEL', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'UPDATEGBN', 'UPDATEDT', 'X', 'Y', 'PHARMTRDAR', 'ASGNYMD'], 'column_types': ['text', 'number', 'text', 'time', 'time', 'number', 'text', 'text', 'text', 'number', 'text', 'number', 'text', 'text', 'time', 'text', 'text', 'text', 'time']}
# --------------------
# Key: seouldata_healthcare_2413
# Value: {'table_names_original': 'GN_FOOD_COLLECT_CHECK', 'column_names_original': ['*', 'CGG_CODE', 'SNT_COB_CODE', 'SNT_COB_NM', 'PLN_SE_CODE', 'PLN_SE_NM', 'CHK_PLN_NM', 'COL_PLN_NM', 'COL_WHY_CODE', 'UPSO_NM', 'ATCL_GUN_CODE', 'ATCL_GUN_NM', 'ATCL_NM', 'EDF_NM', 'RM_NM', 'PDT_UPSO_NM', 'COL_YMD', 'COL_QY_IPT', 'PRD_YMD', 'LOT_NO', 'PRDT_YUTONG_DLN', 'DEPO_STATE_CODE', 'BCE_CODE', 'FACTORY_NM', 'NATIV_FRGNR_SE', 'ISP_SE', 'ISP_REQ_YMD', 'ISP_RT_REPLY_YMD', 'DEAL_SE', 'COL_ISP_SE', 'CTL_REGN_SE', 'COL_PLC_SE', 'DEAL_RT', 'SITE_ADDR', 'DRT_INSP_YMD'], 'column_types': ['text', 'number', 'number', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'time', 'text', 'time', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'time', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'time']}
# --------------------
# Key: seouldata_healthcare_2646
# Value: {'table_names_original': 'SEODAEMUN_ADMIN_MESURE_PUBLIC', 'column_names_original': ['*', 'CGG_CODE', 'ADM_DISPO_YMD', 'GNT_NO', 'SNT_COB_NM', 'SNT_UPTAE_NM', 'UPSO_NM', 'SITE_ADDR_RD', 'ADMM_STATE', 'DISPO_CTN', 'VIOR_SORT', 'VIOR_YMD', 'VIOL_CN', 'DISPO_CTN_DT', 'DISPO_GIGAN', 'INSP_GBN_CODE', 'NT_GBN_CODE', 'JB_ORG', 'TAKE_YMD', 'TRDP_AREA'], 'column_types': ['text', 'number', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'time', 'number']}
# --------------------
# Key: seouldata_healthcare_2665
# Value: {'table_names_original': 'GD_FOOD_HYGIENE_BIZ_LOC_MANAGE', 'column_names_original': ['*', 'GD_FOOD_HYGIENE_CGG_CODE', 'GD_FOOD_HYGIENE_CGG_NM', 'REGN_NM', 'GD_FOOD_HYGIENE_SNT_UPTAE_NM', 'CNT'], 'column_types': ['text', 'number', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_2686
# Value: {'table_names_original': 'DONGDEAMOON_MODEL_RESTAURANT_CANCEL', 'column_names_original': ['*', 'CGG_CODE', 'ASGN_YY', 'ASGN_SNO', 'APPL_YMD', 'ASGN_YMD', 'ASGN_CANCEL_YMD', 'UPSO_NM', 'SITE_ADDR', 'PERM_NT_NO', 'SNT_UPTAE_NM', 'ASGN_CANCEL_WHY', 'MAIN_EDF', 'TRDP_AREA', 'ADMDNG_NM', 'GRADE_FACIL_GBN'], 'column_types': ['text', 'number', 'time', 'text', 'time', 'time', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_3887
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_072209_G_S', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'APVCANCELYMD', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'CLGSTDT', 'CLGENDDT', 'ROPNYMD', 'SITETEL', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEGBN', 'UPDATEDT', 'UPTAENM', 'X', 'Y', 'SNTUPTAENM', 'MANEIPCNT', 'TRDPJUBNSENM', 'LVSENM', 'WTRSPLYFACILSENM', 'FCTYOWKEPCNT', 'FCTYSILJOBEPCNT', 'FCTYPDTJOBEPCNT', 'BDNGOWNSENM', 'FACILTOTSCP', 'JTUPSOASGNNO', 'JTUPSOMAINEDF', 'HOMEPAGE'], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'number', 'number', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_2942
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_072210_D_J', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'CLGSTDT', 'ROPNYMD', 'SITETEL', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEDT', 'UPTAENM', 'Y', 'SNTUPTAENM', 'MANEIPCNT', 'WMEIPCNT', 'TRDPJUBNSENM', 'LVSENM', 'WTRSPLYFACILSENM', 'TOTEPNUM', 'HOFFEPCNT', 'FCTYPDTJOBEPCNT', 'BDNGOWNSENM', 'MONAM', 'FACILTOTSCP'], 'column_types': ['text', 'number', 'text', 'time', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'number', 'number', 'text', 'text', 'number', 'text', 'number', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_4038
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_051801_G_S', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'APVCANCELYMD', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'CLGSTDT', 'CLGENDDT', 'ROPNYMD', 'SITETEL', 'SITEAREA', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'UPDATEGBN', 'UPDATEDT', 'UPTAENM', 'X', 'Y', 'SNTUPTAENM', 'BDNGJISGFLRCNT', 'BDNGUNDERFLRCNT', 'USEJISGSTFLR', 'YANGSILCNT', 'CHAIRCNT', 'CNDPERMNTWHY', 'RCVDRYNCNT', 'ABEDCNT', 'MULTUSNUPSOYN'], 'column_types': ['text', 'number', 'text', 'time', 'text', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_2394
# Value: {'table_names_original': 'JUNGGU_FOOD_COLLECT_CHECK', 'column_names_original': ['*', 'CGG_CODE', 'SNT_COB_CODE', 'SNT_COB_NM', 'PLN_SE_CODE', 'PLN_SE_NM', 'COL_PRFDOC_NO', 'UPSO_NM', 'ATCL_GUN_CODE', 'ATCL_GUN_NM', 'ATCL_NM', 'PRDT_NM', 'PDT_UPSO_NM', 'COL_YMD', 'COL_QUA', 'PRDT_SIZE', 'COL_UNIT', 'PRD_YMD', 'PRDT_YUTONG_DLN', 'DEPO_STATE_CODE', 'BCE_CODE', 'CHD_SMBL_FD_KD_CODE', 'ISP_REQ_ORG_NM', 'FACTORY_NM', 'NATIV_FRGNR_SE', 'NTN', 'ISP_REQ_YMD', 'COL_ISP_RT_GBN', 'COL_ISP_SE', 'CTL_REGN_SE', 'COL_PDT_DEAL', 'GNT_NO', 'DRT_INSP_YMD'], 'column_types': ['text', 'number', 'number', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'time', 'number', 'text', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'time', 'text', 'text', 'text', 'text', 'number', 'time']}
# --------------------
# Key: seouldata_healthcare_2438
# Value: {'table_names_original': 'GEUMCHEON_PUBLIC_HYGIENE_BIZ_LOC_MANAGE', 'column_names_original': ['*', 'GC_FOOD_HYGIENE_CGG_CODE', 'GC_FOOD_HYGIENE_CGG_NM', 'REGN_NM', 'SNT_COB_NM', 'CNT'], 'column_types': ['text', 'number', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_2606
# Value: {'table_names_original': 'SEODAEMUN_ADMIN_MESURE_FOOD', 'column_names_original': ['*', 'CGG_CODE', 'ADM_DISPO_YMD', 'GNT_NO', 'SNT_COB_NM', 'SNT_UPTAE_NM', 'UPSO_NM', 'SITE_ADDR_RD', 'SITE_ADDR', 'DRT_INSP_YMD', 'DISPO_CTN', 'BAS_LAW', 'VIOR_YMD', 'VIOL_CN', 'INSP_GBN_CODE', 'NT_GBN_CODE', 'TAKE_YMD', 'MNG_GBN_NM'], 'column_types': ['text', 'number', 'time', 'number', 'text', 'text', 'text', 'text', 'text', 'time', 'text', 'text', 'time', 'text', 'text', 'text', 'time', 'text']}
# --------------------
# Key: seouldata_healthcare_2692
# Value: {'table_names_original': 'GWANGJIN_FOOD_HYGIENE_BIZ_LOC_MANAGE', 'column_names_original': ['*', 'GJ_FOOD_HYGIENE_CGG_CODE', 'GJ_FOOD_HYGIENE_CGG_NM', 'REGN_NM', 'SNT_UPTAE_NM', 'CNT'], 'column_types': ['text', 'number', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_2739
# Value: {'table_names_original': 'JUNGNANG_MODEL_RESTAURANT_DESIGNATE', 'column_names_original': ['*', 'JN_RESTAURANT_CGG_CODE', 'JN_RESTAURANT_ASGN_YY', 'JN_RESTAURANT_ASGN_SNO', 'JN_RESTAURANT_APPL_YMD', 'JN_RESTAURANT_ASGN_YMD', 'UPSO_NM', 'SNT_UPTAE_NM', 'MAIN_EDF', 'JN_RESTAURANT_TRDP_AREA', 'ADMDNG_NM', 'JN_RESTAURANT_UPSO_SITE_TELNO'], 'column_types': ['text', 'number', 'time', 'text', 'time', 'time', 'text', 'text', 'text', 'number', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_4000
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_072201_N_W', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'APVCANCELYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'SITETEL', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEGBN', 'UPDATEDT', 'UPTAENAME', 'Y', 'SNTUPTAENM', 'MANEIPCNT', 'TRDPJUBNSENM', 'WTRSPLYFACILSENM', 'TOTEPNUM', 'HOFFEPCNT', 'FCTYOWKEPCNT', 'FCTYSILJOBEPCNT', 'FCTYPDTJOBEPCNT', 'BDNGOWNSENM', 'ISREAM', 'MONAM', 'MULTUSNUPSOYN', 'FACILTOTSCP', 'JTUPSOASGNNO', 'JTUPSOMAINEDF', 'HOMEPAGE'], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'number', 'number', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_3510
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_062001_S_C', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'CLGENDDT', 'ROPNYMD', 'SITETEL', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEGBN', 'UPDATEDT', 'UPTAENM', 'X', 'Y', 'SNTUPTAENM', 'BDNGJISGFLRCNT', 'BDNGUNDERFLRCNT', 'USEJISGSTFLR', 'HANSHILCNT', 'YANGSILCNT', 'YOKSILCNT', 'CHAIRCNT', 'BDNGOWNSENM', 'WASHMCCNT', 'WMEIPCNT', 'ABEDCNT', 'MULTUSNUPSOYN'], 'column_types': ['text', 'number', 'text', 'time', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_2146
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_072203_J_N', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'APVCANCELYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DTLSTATEGBN', 'DCBYMD', 'CLGENDDT', 'ROPNYMD', 'SITETEL', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEGBN', 'UPDATEDT', 'UPTAENM', 'X', 'Y', 'SNTUPTAENM', 'WMEIPCNT', 'WTRSPLYFACILSENM', 'TOTEPNUM', 'HOFFEPCNT', 'FCTYOWKEPCNT', 'FCTYSILJOBEPCNT', 'FCTYPDTJOBEPCNT', 'BDNGOWNSENM', 'ISREAM', 'MONAM', 'MULTUSNUPSOYN', 'FACILTOTSCP', 'JTUPSOMAINEDF'], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'text', 'number', 'time', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_1951
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_010105_G_R', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'APVCANCELYMD', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'CLGSTDT', 'SITETEL', 'SITEAREA', 'SITEWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEGBN', 'UPDATEDT', 'UPTAENM', 'X', 'Y', 'STORETRDAR'], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_2245
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_010105_G_A', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'APVCANCELYMD', 'TRDSTATEGBN', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'ROPNYMD', 'SITETEL', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEGBN', 'UPDATEDT', 'UPTAENM', 'X', 'Y'], 'column_types': ['text', 'number', 'text', 'time', 'text', 'number', 'number', 'text', 'time', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_3134
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_114401_G_J', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'CLGSTDT', 'CLGENDDT', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEDT', 'UPTAENM', 'X', 'Y', 'SNTUPTAENM', 'BDNGJISGFLRCNT', 'USEJISGSTFLR', 'USEUNDERENDFLR', 'HANSHILCNT', 'BALHANSILYN', 'CHAIRCNT', 'CNDPERMENDYMD', 'BDNGOWNSENM', 'WMEIPCNT', 'RCVDRYNCNT', 'ABEDCNT', 'MULTUSNUPSOYN'], 'column_types': ['text', 'number', 'text', 'time', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'text', 'number', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'time', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_4079
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_072205_Y_D', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'APVCANCELYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'CLGENDDT', 'ROPNYMD', 'SITETEL', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'UPDATEDT', 'UPTAENM', 'X', 'Y', 'LINDJOBGBNNM', 'LINDPRCBGBNNM', 'LINDSEQNO', 'RGTMBDSNO', 'TOTEPNUM'], 'column_types': ['text', 'number', 'number', 'time', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'time', 'text', 'text', 'text', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_545
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_072204', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'APVCANCELYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DTLSTATENM', 'DCBYMD', 'ROPNYMD', 'SITETEL', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEGBN', 'UPDATEDT', 'UPTAENM', 'X', 'Y', 'LINDJOBGBNNM', 'LINDPRCBGBNNM', 'LINDSEQNO', 'RGTMBDSNO', 'TOTEPNUM'], 'column_types': ['text', 'number', 'number', 'time', 'time', 'number', 'text', 'text', 'time', 'time', 'text', 'text', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_2675
# Value: {'table_names_original': 'GB_MODEL_RESTAURANT_CANCEL', 'column_names_original': ['*', 'CGG_CODE', 'ASGN_SNO', 'APPL_YMD', 'ASGN_YMD', 'ASGN_CANCEL_YMD', 'UPSO_NM', 'SITE_ADDR', 'SNT_UPTAE_NM', 'ASGN_CANCEL_WHY', 'MAIN_EDF', 'TRDP_AREA', 'ADMDNG_NM'], 'column_types': ['text', 'number', 'text', 'time', 'time', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_1431
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_010102_G_N', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DTLSTATENM', 'DCBYMD', 'SITETEL', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEGBN', 'UPDATEDT', 'UPTAENM', 'X', 'Y', 'METRORGASSRNM', 'METRPNUM', 'HSTRMNUM', 'SICBNUM', 'TOTAR', 'MEDEXTRITEMSCNNM', 'ASGNCANCELYMD', 'MITMDCASGNTYPE', 'MITMDCDEPNM', 'EMERCARSPEC', 'EMERCARGEN', 'TOTEPNUM', 'RESCNT', 'FRSTASGNYMD'], 'column_types': ['text', 'number', 'text', 'time', 'number', 'text', 'text', 'time', 'text', 'number', 'text', 'text', 'number', 'text', 'number', 'text', 'time', 'text', 'number', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_2435
# Value: {'table_names_original': 'SEODAEMUN_PUBLIC_HYGIENE_BIZ_LOC_MANAGE', 'column_names_original': ['*', 'SDJ_FOOD_HYGIENE_CGG_CODE', 'SDJ_FOOD_HYGIENE_CGG_NM', 'SDJ_FOOD_HYGIENE_REGN_NM', 'SDJ_FOOD_HYGIENE_SNT_COB_NM', 'SDJ_FOOD_HYGIENE_CNT'], 'column_types': ['text', 'number', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_2495
# Value: {'table_names_original': 'JONGNO_PUBLIC_HYGIENE_BIZ_PUBLIC_USE_FACILITY', 'column_names_original': ['*', 'CGG_CODE', 'SNT_COB_CODE', 'YY', 'UPSO_SNO', 'SNT_COB_NM', 'UPSO_GSL_YMD', 'UPSO_NM', 'TRDP_AREA', 'BUP_NM', 'SITE_STDT', 'ADMDNG_NM', 'DCB_YMD', 'ED_FIN_YMD', 'HANSHIL', 'CHAIR_NUM', 'YOKSIL', 'WASHMC_NUM', 'PERM_NT_NO', 'NTN', 'SITE_ADDR_RD', 'SITE_ADDR'], 'column_types': ['text', 'number', 'number', 'time', 'number', 'text', 'time', 'text', 'number', 'text', 'time', 'text', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_2706
# Value: {'table_names_original': 'DJ_MODEL_RESTAURANT_CANCEL', 'column_names_original': ['*', 'CGG_CODE', 'ASGN_YY', 'ASGN_SNO', 'APPL_YMD', 'ASGN_YMD', 'ASGN_CANCEL_YMD', 'SITE_ADDR_RD', 'SNT_UPTAE_NM', 'ASGN_CANCEL_WHY', 'TRDP_AREA', 'ADMDNG_NM', 'GRADE_FACIL_GBN'], 'column_types': ['text', 'number', 'time', 'text', 'time', 'time', 'time', 'text', 'text', 'text', 'number', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_3295
# Value: {'table_names_original': 'L_O_C_A_L_D_A_T_A_010204_Y_C', 'column_names_original': ['*', 'OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'CLGSTDT', 'CLGENDDT', 'ROPNYMD', 'SITETEL', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'BPLCNM', 'LASTMODTS', 'UPDATEDT', 'UPTAENM', 'X', 'Y', 'CRFTUSEMOTNUM', 'ACETNUM', 'DENTIUSEPRESSNUM', 'EFURNUM', 'PCANNUM', 'SPWVCLERNUM', 'SUVYNUM', 'VITRNUM', 'TRMNUM', 'CRFTUSECOMPRECNT', 'PINDEXCNT'], 'column_types': ['text', 'number', 'text', 'time', 'number', 'text', 'time', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'text', 'number', 'time', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_2799
# Value: {'table_names_original': 'JUNGNANG_FOOD_HYGIENE_BIZ_LOC_MANAGE', 'column_names_original': ['*', 'JRN_FOOD_HYGIENE_CGG_CODE', 'JRN_FOOD_HYGIENE_CGG_NM', 'REGN_NM', 'SNT_UPTAE_NM', 'CNT'], 'column_types': ['text', 'number', 'text', 'text', 'text', 'text']}
# --------------------
# Key: seouldata_healthcare_3754
# ...
# --------------------
# Key: publicdata_climate_13048
# Value: {'table_names_original': 'C_STS_W_DISCHARGERS_GWWJ_WORKP', 'column_names_original': ['*', 'WASTE_CLASH', 'TRADE_NMI', 'BUSINESS_RE_NUMJ', 'WASTE_TYPEK', 'CONTACT_USL', 'CARRIER_NMM', 'PROCESSING_BUSINESS_NMN', 'PROCESSING_METHODO', 'B_S_N_A_XZ', 'RPING_BASE_YEARQ', 'DATA_BASE_DTR', 'SERIAL_NUMD', 'SORTATIONE', 'BUILDING_NMF', 'SAME_NMG', 'ADDRESS_ROAD_NM_ADDRESSH', 'AREAI', 'LATITUDEJ', 'HARDNESSK'], 'column_types': ['text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'time', 'time', 'number', 'text', 'text', 'text', 'text', 'number', 'number', 'number']}
# --------------------
# Key: seoulpopulation_publicadministration_30
# Value: {'table_names_original': 'POP_030', 'column_names_original': ['*', 'STATS_YR', 'SIGUNGU_NM', 'SEX_NM', 'AGEGRD_NM', 'MVMN_TYPE_NM', 'POPL_CNT', 'ADMDONG_CD', 'AGEGRD_CD'], 'column_types': ['text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'number']}
# --------------------
# Key: seoulpopulation_publicadministration_21
# Value: {'table_names_original': 'POP_021', 'column_names_original': ['*', 'STATS_YR', 'SIGUNGU_NM', 'AGEGRD_NM', 'BIRTH_CNT', 'AGEGRD_CD', 'ADMDONG_CD'], 'column_types': ['text', 'text', 'text', 'text', 'number', 'number', 'text']}
# --------------------
# Key: seoulpopulation_publicadministration_25
# Value: {'table_names_original': 'POP_025', 'column_names_original': ['*', 'STATS_YR', 'SIGUNGU_NM', 'AGEGRD_NM', 'SEX_NM', 'DTH_CNT', 'DTH_RT', 'AGEGRD_CD', 'ADMDONG_CD'], 'column_types': ['text', 'number', 'text', 'text', 'text', 'number', 'number', 'number', 'number']}
# --------------------
# Key: seoulpopulation_publicadministration_10
# Value: {'table_names_original': 'POP_010', 'column_names_original': ['*', 'STATS_YR', 'SIGUNGU_NM', 'EPMNDN_NM', 'HSHLD_TYPE_NM', 'HSHLD_CNT', 'ADMDONG_CD', 'HSHLD_TYPE_CD'], 'column_types': ['text', 'text', 'text', 'text', 'text', 'number', 'text', 'text']}
# --------------------
# Key: seoulpopulation_publicadministration_3
# Value: {'table_names_original': 'POP_003', 'column_names_original': ['*', 'STATS_YR', 'SIGUNGU_NM', 'EPMNDN_NM', 'SEX_NM', 'AGEGRD_NM', 'POPL_CNT', 'ADMDONG_CD', 'AGEGRD_CD'], 'column_types': ['text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'number']}
# --------------------
# Key: publicdata_transportation_1564
# Value: {'table_names_original': 'CURRENT_STS_PASSENGERS_BUS_STOP_GWANGJU', 'column_names_original': ['*', 'RECTIFICATION', 'STOP_NUMBER_ARS_ID', 'KWON_JONG_SEON', 'RIDING', 'TRANSACTION_CNT'], 'column_types': ['text', 'text', 'number', 'text', 'text', 'number']}
# --------------------
# Key: publicdata_transportation_618
# Value: {'table_names_original': 'STS_AGM_INSPECTION_IPAB_VESSELS', 'column_names_original': ['*', 'INSPECTION_YEAR', 'TYPE_SHIP', 'SHIP_WEIGHT', 'INSPECTION_FEE_KRW_1_000', 'NUMBER_CASES_DEFAULT', 'NUMBER_CASES_SURCHARGE'], 'column_types': ['text', 'number', 'text', 'text', 'number', 'number', 'number']}
# --------------------
# Key: publicdata_transportation_206
# Value: {'table_names_original': 'MAJOR_SPECIFICATIONS_KALIS_P_BRIDGE_FAC', 'column_names_original': ['*', 'FACILITY_NAME', 'ADDRESS', 'BRIDGE_TYPE', 'BRIDGE_EXTENSION', 'LANE_NUMBER', 'SPAN_NUMBER', 'MAXIMUM_SPAN_COUNT'], 'column_types': ['text', 'text', 'text', 'text', 'number', 'number', 'number', 'number']}
# --------------------
# Key: publicdata_transportation_858
# Value: {'table_names_original': 'NUM_PEOPLE_GETTING_OFF_BTC_TIME_ZONE', 'column_names_original': ['*', 'REVERSE_NUMBER', 'STATION_NAME', 'YEAR_MONTH_DAY', 'DAY_OF_THE_WEEK', 'DIVISION', 'TOTAL', 'H_01_02', 'H_02_03', 'H_03_04', 'H_04_05', 'H_05_06', 'H_06_07', 'H_07_08', 'H_08_09', 'H_09_10', 'H_10_11', 'H_11_12', 'H_12_13', 'H_13_14', 'H_14_15', 'H_15_16', 'H_16_17', 'H_17_18', 'H_18_19', 'H_19_20', 'H_20_21', 'H_21_22', 'H_22_23', 'H_23_24', 'H_24_01'], 'column_types': ['text', 'number', 'text', 'time', 'text', 'text', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number']}
# --------------------
# Key: publicdata_transportation_946
# Value: {'table_names_original': 'SELMETRO_MONTHLY_DROP_OFF_NUM', 'column_names_original': ['*', 'ANNUAL', 'LINE', 'REVERSE_NUMBER', 'STATION_NAME', 'JANUARY_2022', 'FEBRUARY_2022', 'MARCH_2022', 'APRIL_2022', 'MAY_2022'], 'column_types': ['text', 'number', 'number', 'number', 'text', 'number', 'number', 'number', 'number', 'number']}
# --------------------
# Key: publicdata_transportation_724
# Value: {'table_names_original': 'INCHEON_SEO_GU_BICYCLE_FAC', 'column_names_original': ['*', 'CATEGORY', 'INSTALLATION_LOCATION', 'ADDRESS', 'TOTAL_NUMBER_OF_STORAGE', 'AIR_INJECTION', 'DATA_STANDARD_DATE'], 'column_types': ['text', 'text', 'text', 'text', 'number', 'text', 'time']}
# --------------------
# Key: publicdata_transportation_2774
# Value: {'table_names_original': 'C_STS_GGAY_SPACE_INFO_SYS_SPEED_BARRIER', 'column_names_original': ['*', 'MANAGEMENT_NUMY', 'STORM_SURGEZ', 'EXTA', 'JURISDICTIONB', 'INS_DTC'], 'column_types': ['text', 'number', 'number', 'number', 'text', 'time']}
# --------------------
# Key: publicdata_transportation_3032
# Value: {'table_names_original': 'I_STS_GG_SU_BUS_ARRIVAL_INFO', 'column_names_original': ['*', 'SERIAL_NUMB', 'NM_BUS_STOPC', 'BUS_STOP_NUMD', 'YEAR_INSE', 'EQUIPMENT_TYPEF', 'EQUIPMENT_TYPEG'], 'column_types': ['text', 'number', 'text', 'number', 'number', 'text', 'text']}
# --------------------
# Key: publicdata_transportation_3631
# Value: {'table_names_original': 'GNJJ_BUS_INFO_GUIDE_I_STS', 'column_names_original': ['*', 'NUMB', 'BUS_STOPC', 'NM_BUS_STOPD', 'DIRECTIONE', 'SORTATIONF', 'ADDRESSG', 'INS_YEARH', 'DATA_BASE_DTI'], 'column_types': ['text', 'number', 'number', 'text', 'text', 'text', 'text', 'text', 'time']}
# --------------------
# Key: publicdata_transportation_3850
# Value: {'table_names_original': 'GGGJ_ADJACENT_AREA_TRAVEL_ROUTE', 'column_names_original': ['*', 'GEOGRAPHICAL_FEATURE_CDI', 'DESTINATIONJ', 'TRANSIT_ROUTEK'], 'column_types': ['text', 'text', 'text', 'text']}
# --------------------
# Key: publicdata_transportation_1940
# Value: {'table_names_original': 'KOTSA_AUTOMOBILE_MANUFACTURING_DEFECT_REPORT_INFO', 'column_names_original': ['*', 'DATE_OF_RECEIPT', 'PRODUCER', 'NOMINATION', 'MODEL_YEAR'], 'column_types': ['text', 'time', 'text', 'text', 'number']}
# --------------------
# Key: publicdata_transportation_4397
# Value: {'table_names_original': 'P_GETTING_OUT_KORAIL_METROPOLITAN_RAILWAY_STATION_STATION', 'column_names_original': ['*', 'STATION_NMP', 'RIDINGQ', 'STOPOVERR'], 'column_types': ['text', 'text', 'number', 'number']}
# --------------------
# Key: publicdata_transportation_1207
# Value: {'table_names_original': 'MONTHLY_STS_ILLEGAL_PARKING_CONTROL_GANGDONG_GU_SEOUL', 'column_names_original': ['*', 'TRIAL_NAME', 'CITIES_AND_COUNTIES', 'CRACKDOWN', 'NUMBER_OF_CRACKDOWNS'], 'column_types': ['text', 'text', 'text', 'text', 'number']}
# --------------------
# Key: publicdata_transportation_2338
# Value: {'table_names_original': 'STS_GGBC_VE_TAX_DEFERRED_VE_LICENSE_PLATE_RETENTION', 'column_names_original': ['*', 'SERIAL_NUMP', 'RETENTION_DTQ', 'VEHICLE_NUMR', 'NUM_ARREARSS', 'AMT_ARREARST', 'PLACE_DETENTIONU', 'RETURN_DTV'], 'column_types': ['text', 'number', 'time', 'text', 'number', 'number', 'text', 'time']}
# --------------------
# Key: publicdata_transportation_6671
# Value: {'table_names_original': 'STS_KORAIL_FREIGHT_STATION', 'column_names_original': ['*', 'AREAX', 'STATION_NMY'], 'column_types': ['text', 'text', 'text']}
# --------------------
# Key: publicdata_transportation_6389
# Value: {'table_names_original': 'STS_R_VESSELS_UNDER_MOF_VESSELS_ACT', 'column_names_original': ['*', '_WALL_MONTHLYS', 'TONE_CLAST', 'SORTATIONU', 'SUM_TOTALV', 'Y_5_UNDERW', 'Y_5_10_UNDERX', 'Y_10_15_UNDERY', 'Y_15_20_UNDERZ', 'Y_20_25_UNDERA', 'Y_25_30_UNDERB', 'Y_30_35_UNDERC', 'Y_35_MORED'], 'column_types': ['text', 'text', 'text', 'text', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number']}
# --------------------
# Key: publicdata_transportation_10354
# Value: {'table_names_original': 'EX_HI_PASS_TERMINAL_S_OFFICE_INFO', 'column_names_original': ['*', 'HEADQUARTERS', 'NAME', 'BUSINESS_CALL', 'PHONE_NUMBER', 'FAX_NUMBER', 'ZIP_CODE', 'ADDRESS', 'DIVISION', 'BUSINESS_OFFICE', 'HIGH_PASS_USAGE_RATE', 'NOTE'], 'column_types': ['text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'number', 'text']}
# --------------------
# Key: publicdata_transportation_11061
# Value: {'table_names_original': 'SELMETRO_ELEVATOR_I_INFO', 'column_names_original': ['*', 'ANNUAL', 'LINE', 'STATION_NAME', 'EQUIPMENT', 'AORY', 'ELEVATOR_NUMBER', 'OPERATING_SECTION', 'INSTALLATION_LOCATION', 'LINE', 'STATION_NAME', 'LOCATION', 'ORNAMENT', 'TYPE', 'WRITER', 'QUANTITY'], 'column_types': ['text', 'number', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'text', 'text', 'text', 'number']}
# --------------------
# Key: publicdata_education_1654
# Value: {'table_names_original': 'DETAILS_BUSAN_HUMAN_RESOURCES_DEV_INSTITUTE_EDU_O_SYS', 'column_names_original': ['*', 'COURSE_NUMBER', 'EVALUATION_ITEM_ID', 'COURSE_ORDER_ID', 'EVALUATION_ITEM_CODE', 'EVALUATION_PORT', 'EVALUATION_ITEM', 'TOTAL_SCORE', 'AUTHOR_NUMBER', 'DATE_OF_ISSUE', 'EVALUATION'], 'column_types': ['text', 'number', 'number', 'text', 'number', 'text', 'number', 'number', 'number', 'time', 'number']}
# --------------------
# Key: publicdata_education_390
# Value: {'table_names_original': 'APP_LIBRARY_CLUBS_BORYEONG_CHUNGNAM', 'column_names_original': ['*', 'APPLICATION_DATE', 'APPLICATION_TIME', 'MEETING_NAME', 'PURPOSE_OF_USE', 'DATA_STANDARD_DATE'], 'column_types': ['text', 'time', 'text', 'text', 'text', 'time']}
# --------------------
# Key: publicdata_education_2527
# Value: {'table_names_original': 'KRIVET_AUTHORIZED_PRIVATE_Q_REG_STS', 'column_names_original': ['*', 'COMPETENT_MINISTRIESE', 'QUALIFICATION_ITEMSF', 'RATINGG', 'QUALIFICATION_MANAGERH', 'A_V_P_B_J', 'E_A_V_P_K', 'START_STOMATAL_PERIODK', 'E_O_S_P_M'], 'column_types': ['text', 'text', 'text', 'text', 'text', 'time', 'time', 'time', 'time']}
# --------------------
# Key: publicdata_education_4603
# Value: {'table_names_original': 'KOSAF_YOUTH_EDU_MNG_ASSIGNMENT_AMT_DETAILS', 'column_names_original': ['*', 'PRODUCT_NMJ', 'ALLOC_YEARK', 'ASSIGNMENT_CLASL', 'ASSIGNMENT_SERIAL_NUMM', 'NM_UNIVERSITYN', 'TOTAL_ALLOC_AMTO', 'A_A_1_S_Z', 'A_A_2_S_ZZ', 'ALLOC_DTR'], 'column_types': ['text', 'text', 'number', 'text', 'number', 'text', 'number', 'number', 'number', 'time']}
# --------------------
# Key: publicdata_education_4675
# Value: {'table_names_original': 'BASIC_HISTORY_N_TREASURY_I_PROFIT_KOSAF_YOUTH_EDU_MNG', 'column_names_original': ['*', 'PRODUCT_CDN', 'YEARO', 'SEMESTERP', 'UNIVERSITY_CDQ', 'INTEREST_ACCRUAL_DTR', 'DETAILED_DT_TIME_CHANGES', 'INTEREST_INCOME_AMTT', 'DT_TIME_INITIAL_REU', 'LAST_CHANGE_DT_TIMEV'], 'column_types': ['text', 'text', 'number', 'number', 'text', 'time', 'time', 'number', 'time', 'time']}
# --------------------
# Key: publicdata_education_4683
# Value: {'table_names_original': 'KOSAF_STATEMENT_FINANCIAL_POSITION', 'column_names_original': ['*', 'SJD', 'E_13TH_PARTY_ORIGIN_1E', 'E_13TH_PARTY_ORIGIN_2F', 'E_1_E_O_1_ZZ', 'E_1_E_O_2_VA'], 'column_types': ['text', 'text', 'number', 'number', 'number', 'number']}
# --------------------
# Key: publicdata_education_4544
# Value: {'table_names_original': 'C_STS_MENTORING_MENTORS_COLLEGE_STUDENTS_KOSAF_SOCIAL_LEADER', 'column_names_original': ['*', 'NUML', 'YEARM', 'GENDERN', 'SPECIALIZED_DEPARTMENTO', 'PARTICIPANT_CLASP'], 'column_types': ['text', 'number', 'number', 'text', 'text', 'text']}
# --------------------
# Key: publicdata_education_5088
# Value: {'table_names_original': 'HRDK_HRD4U_CONTENT_STS', 'column_names_original': ['*', 'CONTENT_TYPEW', 'CONTENT_FIELDX', 'CONTENT_NMY', 'NEXT_NMZ', 'PRODUCTION_DTA', 'SOURCESB'], 'column_types': ['text', 'text', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: publicdata_education_6575
# Value: {'table_names_original': 'D_P_I_L_K_L_A_K_C_I_K_L_I_AM', 'column_names_original': ['*', 'NUMJ', 'RE_DTK', 'PRODUCER_CDL', 'ORAL_INF_CONNECTION_NUMM'], 'column_types': ['text', 'number', 'text', 'text', 'text']}
# --------------------
# Key: publicdata_education_5093
# Value: {'table_names_original': 'GBE_GB_YECHEON_O_EDU_C_STS_HAGWON', 'column_names_original': ['*', 'SORTATIONE', 'NUMF', 'NM_ACADEMYG', 'ADDRESSH', 'PHONE_NUMI'], 'column_types': ['text', 'text', 'number', 'text', 'text', 'text']}
# --------------------
# Key: publicdata_education_5473
# Value: {'table_names_original': 'STS_SU_KASFO_HAPPY_DORMITORY_PRO', 'column_names_original': ['*', 'YEARG', 'SCHOOL_NM_BUSINESS_NMH', 'CPI', 'T_P_C_1_M_W_Q', 'METER_SQUARE_FLOOR_AREAK', 'P_F_F_R_S', 'FINANCIAL_HOUSING_FUNDM', 'F_R_T_U', 'GOVERNMENT_SUBSIDYO', 'PROGRESS_STAP'], 'column_types': ['text', 'number', 'text', 'number', 'number', 'number', 'number', 'number', 'number', 'text', 'text']}
# --------------------
# Key: publicdata_education_5329
# Value: {'table_names_original': 'KASFO_TRAINING_PRO_TRAINING_MNG_TRAINING_INFO', 'column_names_original': ['*', 'TRAINING_NUMJ', 'HOTEL_ORDERK', 'HOTEL_UNIQUE_NUML', 'ROOM_NUMM', 'DISCLOSURE_STAN', 'TYPEO', 'CPP', 'NUM_APPLICANTSQ', 'GENDER_DISTINCTIONR', 'PRIVATE_ROOM_STAS', 'DT_ENTRYT', 'INPUT_PERSONU', 'REVISION_DTV'], 'column_types': ['text', 'text', 'number', 'number', 'number', 'text', 'number', 'number', 'number', 'text', 'text', 'text', 'text', 'text']}
# --------------------
# Key: publicdata_education_6709
# Value: {'table_names_original': 'GWE_TEACHING_CNT_STS', 'column_names_original': ['*', 'NM_TEACHING_CALLA', 'NM_INSTRUCTORB', 'RE_STAC', 'PHONE_NUMD', 'TEACHING_ADDRESSE', 'NUM_PEOPLE_TEMPORARY_CPF', 'TOTAL_QUOTAG', 'FIELD_CLASH', 'TEACHING_SERIESI', 'TEACHING_COURSEJ', 'TEACHING_CLASSK', 'PERIOD_INSTRUCTIONL', 'TOTAL_TRAINING_HOURSM', 'TEACHING_FEEN', 'TEACHING_FEE_PER_HOURO', 'TEXTBOOK_EXPENSESP', 'MOCK_TEST_FEEQ', 'MATERIAL_COSTR', 'SCHOOL_MEAL_EXPENSESS', 'COST_SNACKST', 'DORMITORY_FEEU', 'COST_VEHICLEV', 'OTHER_EXPENSESW', 'CLOTHING_COSTX', 'TOTAL_OTHER_EXPENSESY', 'TOTAL_COST_TEACHINGZ', 'T_T_F_P_H_J'], 'column_types': ['text', 'text', 'text', 'text', 'text', 'text', 'number', 'number', 'text', 'text', 'text', 'text', 'text', 'number', 'text', 'text', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'number', 'text', 'text']}
# --------------------
# Key: publicdata_education_6711
# Value: {'table_names_original': 'GWE_SCHOOL_STS', 'column_names_original': ['*', 'JURISDICTIONG', 'NM_SCHOOLH', 'ADDRESSI', 'PHONE_NUMJ', 'HOMEPAGEK'], 'column_types': ['text', 'text', 'text', 'text', 'number', 'text']}
# --------------------
# Key: publicdata_education_13524
# Value: {'table_names_original': 'LIST_GGIC_POPULAR_BOOKS', 'column_names_original': ['*', 'NUMQ', 'BOOK_NMR', 'AUTHORS', 'PUBLISHING_HOUSET', 'YEAR_ISSUE_YEARU', 'NUM_LOANSV', 'BASE_QUARTERW', 'CITY_COUNTY_NMM', 'LIBRARY_NMN', 'BOOK_NMO', 'I_S_B_N_Q', 'C_S_K_D_C_M_RC', 'DT_TIME_LOANR', 'DATA_BASE_DTS'], 'column_types': ['text', 'number', 'text', 'text', 'text', 'number', 'number', 'text', 'text', 'text', 'text', 'text', 'number', 'time', 'time']}
# --------------------

# %% [markdown]
# 1-2. lable된 data 불러오기

# %%
def merge_json_files_to_dataframe(root_dir):
    """
    Merges all JSON files in subfolders of the root directory into a single DataFrame.

    Args:
        root_dir: The path to the root directory.

    Returns:
        A Pandas DataFrame containing the merged data.
    """
    df = pd.DataFrame()  # Create DataFrame

    for dirpath, dirnames, filenames in os.walk(root_dir):
        for filename in filenames:
            if filename.endswith('.json'):
                filepath = os.path.join(dirpath, filename)
                print(filepath)
                with open(filepath, 'r', encoding='utf-8') as f:
                    try:
                        data = json.load(f)
                        df_temp = pd.DataFrame(data["data"])
                        df = pd.concat([df, df_temp])
                    except json.JSONDecodeError as e:
                        print(f"Error decoding JSON in file: {filepath}")
                        print(f"Error message: {e}")

    return df

# %%
# 구글 드라이브 폴더 경로를 지정합니다.
folder_path_val = '/content/drive/MyDrive/Project1/Data/Validation/SQLs'

# JSON 파일을 읽어와 병합합니다.
df2_val = merge_json_files_to_dataframe(folder_path_val)
# Out:
# /content/drive/MyDrive/Project1/Data/Validation/SQLs/2. 공공데이터포털/01. 보건/TEXT_NL2SQL_label_publicdata_healthcare.json
# /content/drive/MyDrive/Project1/Data/Validation/SQLs/2. 공공데이터포털/05. 복지/TEXT_NL2SQL_label_publicdata_welfare.json
# /content/drive/MyDrive/Project1/Data/Validation/SQLs/2. 공공데이터포털/08. 교육/TEXT_NL2SQL_label_publicdata_education.json
# /content/drive/MyDrive/Project1/Data/Validation/SQLs/2. 공공데이터포털/03. 문화／관광/TEXT_NL2SQL_label_publicdata_culture.json
# /content/drive/MyDrive/Project1/Data/Validation/SQLs/2. 공공데이터포털/07. 교통/TEXT_NL2SQL_label_publicdata_transportation.json
# /content/drive/MyDrive/Project1/Data/Validation/SQLs/2. 공공데이터포털/04. 산업／경제/TEXT_NL2SQL_label_publicdata_industrialeconomic.json
# /content/drive/MyDrive/Project1/Data/Validation/SQLs/2. 공공데이터포털/02. 일반행정/TEXT_NL2SQL_label_publicdata_publicadministration.json
# /content/drive/MyDrive/Project1/Data/Validation/SQLs/2. 공공데이터포털/06. 환경/TEXT_NL2SQL_label_publicdata_climate.json
# /content/drive/MyDrive/Project1/Data/Validation/SQLs/3. 빅데이터캠퍼스/02. 일반행정/TEXT_NL2SQL_label_seoulpopulation_publicadministration.json
# /content/drive/MyDrive/Project1/Data/Validation/SQLs/1. 서울_열린데이터/06. 환경/TEXT_NL2SQL_label_seouldata_climate.json
# /content/drive/MyDrive/Project1/Data/Validation/SQLs/1. 서울_열린데이터/03. 문화／관광/TEXT_NL2SQL_label_seouldata_culture.json
# /content/drive/MyDrive/Project1/Data/Validation/SQLs/1. 서울_열린데이터/08. 교육/TEXT_NL2SQL_label_seouldata_education.json
# /content/drive/MyDrive/Project1/Data/Validation/SQLs/1. 서울_열린데이터/04. 산업／경제/TEXT_NL2SQL_label_seouldata_industrialeconomic.json
# /content/drive/MyDrive/Project1/Data/Validation/SQLs/1. 서울_열린데이터/05. 복지/TEXT_NL2SQL_label_seouldata_welfare.json
# /content/drive/MyDrive/Project1/Data/Validation/SQLs/1. 서울_열린데이터/02. 일반행정/TEXT_NL2SQL_label_seouldata_publicadministration.json
# /content/drive/MyDrive/Project1/Data/Validation/SQLs/1. 서울_열린데이터/01. 보건/TEXT_NL2SQL_label_seouldata_healthcare.json
# /content/drive/MyDrive/Project1/Data/Validation/SQLs/1. 서울_열린데이터/07. 교통/TEXT_NL2SQL_label_seouldata_transportation.json

# %%
# 병합된 DataFrame을 출력합니다.
print(df2_val.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11026 entries, 0 to 248
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   db_id           11026 non-null  object
#  1   utterance_id    11026 non-null  object
#  2   hardness        11026 non-null  object
#  3   utterance_type  11026 non-null  object
#  4   query           11026 non-null  object
#  5   utterance       11026 non-null  object
#  6   values          11026 non-null  object
#  7   cols            11026 non-null  object
# dtypes: object(8)
# memory usage: 775.3+ KB
# None

# %%
df2_val = df2_val.dropna(subset=['query'])

df2_val.info()
df2_val.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11026 entries, 0 to 248
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   db_id           11026 non-null  object
#  1   utterance_id    11026 non-null  object
#  2   hardness        11026 non-null  object
#  3   utterance_type  11026 non-null  object
#  4   query           11026 non-null  object
#  5   utterance       11026 non-null  object
#  6   values          11026 non-null  object
#  7   cols            11026 non-null  object
# dtypes: object(8)
# memory usage: 775.3+ KB
#                        db_id utterance_id hardness utterance_type  \
# 0  publicdata_healthcare_740    Wht_10645   medium           BR04
# 1  publicdata_healthcare_740    Hch_10647   medium           BR08
# 2  publicdata_healthcare_740    Wht_10646     easy           BR04
# 3  publicdata_healthcare_740    Wht_10647     easy           BR04
# 4  publicdata_healthcare_740    Whr_12929     easy           BR03
#
#                                                query  \
# 0  SELECT CONTACT FROM GYEONGNAM_HEALTH_CLINIC WH...
# 1  SELECT CITIES, COUNT(HEALTH_CARE_CALL) FROM GY...
# 2  SELECT FAX FROM GYEONGNAM_HEALTH_CLINIC WHERE ...
# 3  SELECT CONTACT FROM GYEONGNAM_HEALTH_CLINIC WH...
# 4  SELECT LOCATION FROM GYEONGNAM_HEALTH_CLINIC W...
#
#                          utterance  \
# 0  소재지에 산양읍이 들어가는 보건 진료소의 연락처를 알려줘
# 1             시군별 진료소의 개수와 시군을 보여줘
# 2       사천시에 있는 보건 진료소의 팩스 번호를 알려줘
# 3               학림 보건진료소의 연락처를 알려줘
# 4         진주시가 아닌 보건 진료소의 소재지를 알려줘
#
#                                               values  \
# 0                                                 []
# 1                                                 []
# 2  [{'token': '사천시', 'start': 0, 'column_index': 1}]
# 3   [{'token': '학림', 'start': 0, 'column_index': 2}]
# 4  [{'token': '진주시', 'start': 0, 'column_index': 1}]
#
#                                                 cols
# 0  [{'token': '연락처', 'start': 23, 'column_index':...
# 1  [{'token': '시군', 'start': 13, 'column_index': ...
# 2  [{'token': '팩스 번호', 'start': 16, 'column_index...
# 3  [{'token': '연락처', 'start': 10, 'column_index':...
# 4  [{'token': '소재지', 'start': 16, 'column_index':...

# %% [markdown]
# ## 2. Pytorch 데이터 로더 세팅

# %%
import torch
from torch.utils.data import Dataset, DataLoader

# %%
class SQLDataset(Dataset):
    def __init__(self, df2, schema_dict):
        self.df2 = df2
        self.schema_dict = schema_dict

    def __len__(self):
        return len(self.df2)

    def __getitem__(self, idx):
        row = self.df2.iloc[idx]
        db_id = row['db_id']
        utterance = row['utterance']
        query = row['query']

        if db_id in self.schema_dict:
            table_names = self.schema_dict[db_id]['table_names_original']
            column_names = self.schema_dict[db_id]['column_names_original']
            column_types = self.schema_dict[db_id]['column_types']

            # 여기서 토큰화 및 인코딩 작업을 수행합니다.
            # 예를 들어, utterance, table_names, column_names를 토큰화하고 인덱스로 변환합니다.
            # input_tokens = tokenize_and_encode(utterance, table_names, column_names)

            # 임시로 문자열을 그대로 사용
            input_tokens = f"[CLS]{utterance}[SEP]{table_names}{' '.join(column_names)}"

            # query를 토큰화하고 인덱스로 변환합니다.
            # target_tokens = tokenize_and_encode(query)

            # 임시로 문자열을 그대로 사용
            target_tokens = query

            return input_tokens, target_tokens
        else:
            return None, None

# %%
# df2_val과 schema_val_dict을 사용해서 test를 위한 data loader를 생성

test_dataset = SQLDataset(df2_val, schema_val_dict)
test_dataloader = DataLoader(test_dataset, batch_size=8, shuffle=False)  # 테스트는 shuffle하지 않습니다.

# %%
# 데이터 로더 사용 예시
for input_tokens, target_tokens in test_dataloader:
    # 모델에 input_tokens를 입력하고 target_tokens를 정답으로 사용하여 test
    print(input_tokens[0])
    print(target_tokens[0])
    break # 예시로 첫 번째 배치만 출력
# Out:
# [CLS]소재지에 산양읍이 들어가는 보건 진료소의 연락처를 알려줘[SEP]GYEONGNAM_HEALTH_CLINIC* CITIES HEALTH_CARE_CALL LOCATION CONTACT FAX MEDICAL_TREATMENT CARE_TIME
# SELECT CONTACT FROM GYEONGNAM_HEALTH_CLINIC WHERE LOCATION LIKE '%산양읍%'

# %% [markdown]
# ## 3. Model Test

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# Check if GPU is available, otherwise use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# 모델과 토크나이저를 로드합니다.
model_path = '/content/drive/MyDrive/Project1/fine_tuned_mt5-small_model'
model = AutoModelForSeq2SeqLM.from_pretrained(model_path).to(device)
tokenizer = AutoTokenizer.from_pretrained(model_path)
# Out:
# You set `add_prefix_space`. The tokenizer needs to be converted from the slow tokenizers
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:551: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %%
'''
# 테스트 루프 (예시)
model.eval()  # 모델을 평가 모드로 설정
correct_predictions = 0
total_samples = 0

with torch.no_grad():
    for batch_idx, (input_tokens, target_tokens) in enumerate(test_dataloader):
        inputs = tokenizer(input_tokens, return_tensors="pt", padding=True, truncation=True).to(device)
        targets = tokenizer(target_tokens, return_tensors="pt", padding=True, truncation=True).to(device)

        outputs = model.generate(**inputs)  # generate 함수를 사용하여 SQL 생성

        # 생성된 SQL을 디코딩
        predicted_sqls = tokenizer.batch_decode(outputs, skip_special_tokens=True)

        # 생성된 SQL과 실제 SQL을 비교하여 정확도 계산
        for i in range(len(predicted_sqls)):
            # target_tokens[i]를 토큰화된 상태에서 문자열로 변환
            target_sql = tokenizer.decode(targets.input_ids[i], skip_special_tokens=True)

            # 생성된 SQL과 실제 SQL이 일치하는지 확인
            if predicted_sqls[i] == target_sql:
                correct_predictions += 1

        total_samples += len(predicted_sqls)

        # 중간 과정 정확도 출력
        accuracy = correct_predictions / total_samples
        print(f"Batch {batch_idx + 1}: Accuracy = {accuracy:.4f}")

# 모든 테스트 완료 후 정확도 출력
accuracy = correct_predictions / total_samples
print(f"Overall Accuracy: {accuracy:.4f}")
'''
# Out:
# '\n# 테스트 루프 (예시)\nmodel.eval()  # 모델을 평가 모드로 설정\ncorrect_predictions = 0\ntotal_samples = 0\n\nwith torch.no_grad():\n    for batch_idx, (input_tokens, target_tokens) in enumerate(test_dataloader):\n        inputs = tokenizer(input_tokens, return_tensors="pt", padding=True, truncation=True).to(device)\n        targets = tokenizer(target_tokens, return_tensors="pt", padding=True, truncation=True).to(device)\n\n        outputs = model.generate(**inputs)  # generate 함수를 사용하여 SQL 생성\n\n        # 생성된 SQL을 디코딩\n        predicted_sqls = tokenizer.batch_decode(outputs, skip_special_tokens=True)\n\n        # 생성된 SQL과 실제 SQL을 비교하여 정확도 계산\n        for i in range(len(predicted_sqls)):\n            # target_tokens[i]를 토큰화된 상태에서 문자열로 변환\n            target_sql = tokenizer.decode(targets.input_ids[i], skip_special_tokens=True)\n\n            # 생성된 SQL과 실제 SQL이 일치하는지 확인\n            if predicted_sqls[i] == target_sql:\n                correct_predictions += 1\n\n        total_samples += len(predicted_sqls)\n\n        # 중간 과정 정확도 출력\n        accuracy = correct_predictions / total_samples\n        print(f"Batch {batch_idx + 1}: Accuracy = {accuracy:.4f}")\n\n# 모든 테스트 완료 후 정확도 출력\naccuracy = correct_predictions / total_samples\nprint(f"Overall Accuracy: {accuracy:.4f}")\n'

# %%
def print_query(input_utterance, db_id):
  if db_id in schema_val_dict:
    table_names = schema_val_dict[db_id]['table_names_original']
    column_names = schema_val_dict[db_id]['column_names_original']

    input_tokens = f"[CLS]{input_utterance}[SEP]{table_names}{'[SEP]'.join(column_names)}"

    # 토큰화 및 인코딩
    inputs = tokenizer(input_tokens, return_tensors="pt", padding=True, truncation=True).to(device)

    # 모델 실행
    model.eval()
    with torch.no_grad():
        outputs = model.generate(**inputs)
        predicted_sql = tokenizer.decode(outputs[0], skip_special_tokens=True)

    print("Input Utterance:", input_utterance)
    print("Predicted SQL:", predicted_sql)
  else:
    print(f"DB ID '{db_id}' not found in schema dictionary.")

# %%
# df2_val에서 db_id와 utterance쌍을 요소로 가지는 리스트를 생성

db_utterance_list = []
for index, row in df2_val.iterrows():
  db_id = row['db_id']
  utterance = row['utterance']
  db_utterance_list.append((db_id, utterance))

# %%
print(db_utterance_list[:5])  # 처음 5개 쌍만 출력
# Out:
# [('publicdata_healthcare_740', '소재지에 산양읍이 들어가는 보건 진료소의 연락처를 알려줘'), ('publicdata_healthcare_740', '시군별 진료소의 개수와 시군을 보여줘'), ('publicdata_healthcare_740', '사천시에 있는 보건 진료소의 팩스 번호를 알려줘'), ('publicdata_healthcare_740', '학림 보건진료소의 연락처를 알려줘'), ('publicdata_healthcare_740', '진주시가 아닌 보건 진료소의 소재지를 알려줘')]

# %%
import random

# %%
for db_id, input_utterance in random.sample(db_utterance_list, 5):
  print_query(input_utterance, db_id)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1258: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Input Utterance: 참조 표준 데이터베이스명이 한국인으로 시작하는 센터의 이름을 중복 없이 찾아줘
# Predicted SQL: SELECT DISTINCT CENTER_NMC FROM T_INFO_DB_MAIN
# Input Utterance: 50인 미만으로 운영 중인 평균 업체 수가 20인 미만 업체 수 보다 많고 부동산을 담보로 지원받은 업체가 5곳 이상인 연도를 중복 없이 찾아줘
# Predicted SQL: SELECT DISTINCT T1.YEAR FROM NUM_SU_CO_KOS
# Input Utterance: 위생 업태명이 방문 판매인 업체의 소재지 면적은 얼마야
# Predicted SQL: SELECT SITEAREA FROM L_O_C_A_L_D_
# Input Utterance: 비고에 청소년이 포함되는 의료기관 시설의 이름을 알려줘
# Predicted SQL: SELECT NAME FROM GD_TN_BBS9 WHERE PHONE LIKE
# Input Utterance: 상세 영업 상태명이 영업인 곳의 최종 수정 일자와 사업장명을 보여줘
# Predicted SQL: SELECT LASTMODTS, BPLCNM FROM L_O_C_A
